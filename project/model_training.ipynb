# %% [markdown]
# # **Football Player Segmentation**

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## I. Pre-processing

# %% [markdown]
# ### I.1. Dataset class

# %%
import os
import json
import numpy as np
import torch
from torch.utils.data import Dataset
from PIL import Image
import torchvision.transforms as T
# from torchvision import transforms
from pycocotools import mask as coco_mask
import torch.nn.functional as F_nn


class FootballSegmentDataset(Dataset):
    def __init__(self, root_dir, annotation_file, transforms=None, frame_step=1):
        self.root_dir = root_dir
        self.transforms = transforms
        self.frame_step = frame_step

        with open(annotation_file, 'r') as f:
            self.coco = json.load(f)

        self.image_id_to_info = {img['id']: img for img in self.coco['images']}
        self.id_to_annotations = {}

        for ann in self.coco['annotations']:
            img_id = ann['image_id']
            if img_id not in self.id_to_annotations:
                self.id_to_annotations[img_id] = []
            self.id_to_annotations[img_id].append(ann)

        # Filter image IDs with step
        full_ids = list(self.id_to_annotations.keys())
        self.image_ids = full_ids[::self.frame_step]

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        img_id = self.image_ids[idx]
        img_info = self.image_id_to_info[img_id]
        img_path = os.path.join(self.root_dir, img_info['file_name'])
        img = Image.open(img_path).convert("RGB")

        height, width = img_info['height'], img_info['width']
        anns = self.id_to_annotations[img_id]
        masks = []
        for ann in anns:
            segmentation = ann['segmentation']
            rles = coco_mask.frPyObjects(segmentation, height, width)
            rle = coco_mask.merge(rles)
            m = coco_mask.decode(rle)
            masks.append(m)

        if masks:
            mask = np.any(np.stack(masks, axis=0), axis=0).astype(np.uint8)
        else:
            mask = np.zeros((height, width), dtype=np.uint8)

        mask = Image.fromarray(mask)

        if self.transforms:
            img, mask = self.transforms(img, mask)
        else:
            img = T.ToTensor()(img)
            mask = torch.from_numpy(np.array(mask)).long()

        return img, mask

# %% [markdown]
# ### I.2. Transform

# %%
import random
from torchvision.transforms import functional as F

# Augmentations for TRAINING only
class JointTrainTransform:
    def __init__(self, resize=(256, 256), hflip_prob=0.5, vflip_prob=0.5):
        self.resize = resize
        self.hflip_prob = hflip_prob
        self.vflip_prob = vflip_prob
        self.color_jitter = T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1)
        self.normalize = T.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

    def __call__(self, img, mask):
        img = F.resize(img, self.resize)
        mask = F.resize(mask, self.resize, interpolation=Image.NEAREST)

        if random.random() < self.hflip_prob:
            img = F.hflip(img)
            mask = F.hflip(mask)

        if random.random() < self.vflip_prob:
            img = F.vflip(img)
            mask = F.vflip(mask)

        img = self.color_jitter(img)
        img = F.to_tensor(img)
        mask = torch.from_numpy(np.array(mask)).long()
        img = self.normalize(img)
        return img, mask

# Minimal transform for VAL & TEST
class JointEvalTransform:
    def __init__(self, resize=(256, 256)):
        self.resize = resize
        self.normalize = T.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

    def __call__(self, img, mask):
        img = F.resize(img, self.resize)
        mask = F.resize(mask, self.resize, interpolation=Image.NEAREST)

        img = F.to_tensor(img)
        mask = torch.from_numpy(np.array(mask)).long()
        img = self.normalize(img)
        return img, mask

# %% [markdown]
# ### I.3. Dataset

# %%
import torch.utils.data as data
from torchvision import utils
from torch.utils.data import DataLoader, random_split
from torch.utils.data import Subset

resize=(256, 256)
frame_step=5

# Dataset
train_dataset = FootballSegmentDataset(
    root_dir='dataset1/images',
    annotation_file='dataset1/annotations/instances_default.json',
    transforms=JointTrainTransform(resize=resize),
    frame_step=frame_step
)

val_dataset = FootballSegmentDataset(
    root_dir='dataset1/images',
    annotation_file='dataset1/annotations/instances_default.json',
    transforms=JointEvalTransform(resize=resize),
    frame_step=frame_step
)

test_dataset = FootballSegmentDataset(
    root_dir='dataset1/images',
    annotation_file='dataset1/annotations/instances_default.json',
    transforms=JointEvalTransform(resize=resize),
    frame_step=frame_step
)

# Splitting
#-- Dataset splitting: Train - Val - Test: 70-15-15
#-- Train: 70%
#-- Val: 15% for comparison between models
#-- Test: 15% for final estimation of the model performance

total_size = len(train_dataset)
indices = list(range(total_size))
np.random.seed(42)
np.random.shuffle(indices)

train_size = int(0.7 * total_size)
val_size = int(0.15 * total_size)
test_size = total_size - train_size - val_size

train_idx = indices[:train_size]
val_idx = indices[train_size:train_size + val_size]
test_idx = indices[train_size + val_size:]

trainset = Subset(train_dataset, train_idx)
valset = Subset(val_dataset, val_idx)
testset = Subset(test_dataset, test_idx)

# %% [markdown]
# ## II. Supported functions

# %% [markdown]
# ### Loss function

# %%
import torch.nn as nn

class BCEJaccardWithLogitsLoss(nn.Module):
    def __init__(self, jaccard_weight=1, smooth=1):
        super().__init__()
        self.bce = nn.BCEWithLogitsLoss()
        self.jaccard_weight = jaccard_weight
        self.smooth = smooth

    def forward(self, outputs, targets):
        if outputs.size() != targets.size():
            raise ValueError("size mismatch, {} != {}".format(outputs.size(), targets.size()))
            
        loss = self.bce(outputs, targets)

        if self.jaccard_weight:
            targets = (targets == 1.0).float()
            targets = targets.view(-1)
            outputs = torch.sigmoid(outputs)
            outputs = outputs.view(-1)

            intersection = (targets * outputs).sum()
            union = outputs.sum() + targets.sum() - intersection

            loss -= self.jaccard_weight * torch.log((intersection + self.smooth ) / (union + self.smooth )) # try with 1-dice
        return loss

class BCEDiceWithLogitsLoss(nn.Module):
    def __init__(self, dice_weight=1, smooth=1):
        super().__init__()
        self.bce = nn.BCEWithLogitsLoss()
        self.dice_weight = dice_weight
        self.smooth = smooth
        
    def __call__(self, outputs, targets):
        if outputs.size() != targets.size():
            raise ValueError("size mismatch, {} != {}".format(outputs.size(), targets.size()))
            
        loss = self.bce(outputs, targets)

        targets = (targets == 1.0).float()
        targets = targets.view(-1)
        outputs = F_nn.sigmoid(outputs)
        outputs = outputs.view(-1)

        intersection = (outputs * targets).sum()
        dice = 2.0 * (intersection + self.smooth)  / (targets.sum() + outputs.sum() + self.smooth)
        
        loss -= self.dice_weight * torch.log(dice) # try with 1- dice

        return loss
    
class FocalWithLogitsLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2):
        super().__init__()
        self.bce = nn.BCEWithLogitsLoss()
        self.alpha = alpha
        self.gamma = gamma
        
    def __call__(self, outputs, targets):
        if outputs.size() != targets.size():
            raise ValueError("size mismatch, {} != {}".format(outputs.size(), targets.size()))
            
        loss = self.bce(outputs, targets)

        targets = (targets == 1.0).float()
        targets = targets.view(-1)
        outputs = torch.sigmoid(outputs)
        outputs = outputs.view(-1)
        outputs = torch.where(targets == 1, outputs, 1 - outputs)

        focal = self.alpha * (1 - outputs) ** (self.gamma)
        loss *= focal.mean()

        return loss

def dice_loss(input, target):
    input = torch.sigmoid(input)
    smooth = 1.0

    iflat = input.view(-1)
    tflat = target.view(-1)
    intersection = (iflat * tflat).sum()
    
    return ((2.0 * intersection + smooth) / (iflat.sum() + tflat.sum() + smooth))

class FocalLoss(nn.Module):
    def __init__(self, gamma):
        super().__init__()
        self.gamma = gamma
        
    def forward(self, input, target):
        if not (target.size() == input.size()):
            raise ValueError("Target size ({}) must be the same as input size ({})"
                             .format(target.size(), input.size()))

        max_val = (-input).clamp(min=0)
        loss = input - input * target + max_val + \
            ((-max_val).exp() + (-input - max_val).exp()).log()

        invprobs = F_nn.logsigmoid(-input * (target * 2.0 - 1.0))
        loss = (invprobs * self.gamma).exp() * loss
        
        return loss.mean()

class MixedLoss(nn.Module):
    def __init__(self, alpha, gamma):
        super().__init__()
        self.alpha = alpha
        self.focal = FocalLoss(gamma)
        
    def forward(self, input, target):
        loss = self.alpha*self.focal(input, target) - torch.log(dice_loss(input, target))
        return loss.mean()

# %%
import os
import json
import gc
import itertools
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import DataLoader
from sklearn.metrics import precision_score, recall_score, f1_score

# ========== 1. Define training and validation loop ==========
def train_and_validate(model, trainloader, testloader, criterion, optimizer, num_epochs=10, device='cuda'):
    model = model.to(device)
    train_losses, val_losses = [], []

    for epoch in range(num_epochs):
        print(f"\nEpoch {epoch + 1}/{num_epochs}")
        model.train()
        running_train_loss = 0.0
        for images, masks in trainloader:
            gc.collect()
            torch.cuda.empty_cache()
            images = images.to(device, non_blocking=True)
            masks = masks.to(device, non_blocking=True).unsqueeze(1).float()
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, masks)
            loss.backward()
            optimizer.step()
            running_train_loss += loss.item()
        train_loss = running_train_loss / len(trainloader)
        train_losses.append(train_loss)

        model.eval()
        running_val_loss = 0.0
        with torch.no_grad():
            for images, masks in testloader:
                gc.collect()
                torch.cuda.empty_cache()
                images = images.to(device, non_blocking=True)
                masks = masks.to(device, non_blocking=True).unsqueeze(1).float()
                outputs = model(images)
                loss = criterion(outputs, masks)
                running_val_loss += loss.item()
        val_loss = running_val_loss / len(testloader)
        val_losses.append(val_loss)

        print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")

    return model, train_losses, val_losses

# ========== 2. Evaluation ==========
def evaluate_segmentation_model(model, dataloader, device, threshold=0.5):
    model.eval()
    iou_scores, dice_scores, precisions, recalls, f1s, pixel_accuracies, mae_scores = [], [], [], [], [], [], []
    with torch.no_grad():
        for images, masks in dataloader:
            images = images.to(device)
            masks = masks.to(device).float()
            outputs = model(images)
            preds = torch.sigmoid(outputs)
            preds = (preds > threshold).float()
            preds_flat = preds.view(-1).cpu().numpy()
            masks_flat = masks.view(-1).cpu().numpy()

            intersection = np.logical_and(preds_flat, masks_flat).sum()
            union = np.logical_or(preds_flat, masks_flat).sum()
            iou = intersection / union if union != 0 else 0
            dice = (2 * intersection) / (preds_flat.sum() + masks_flat.sum() + 1e-8)
            pixel_acc = (preds_flat == masks_flat).mean()
            mae = np.abs(preds_flat - masks_flat).mean()

            iou_scores.append(iou)
            dice_scores.append(dice)
            pixel_accuracies.append(pixel_acc)
            mae_scores.append(mae)
            precisions.append(precision_score(masks_flat, preds_flat, zero_division=0))
            recalls.append(recall_score(masks_flat, preds_flat, zero_division=0))
            f1s.append(f1_score(masks_flat, preds_flat, zero_division=0))

    metrics = {
        "IoU": float(np.mean(iou_scores)),
        "Dice": float(np.mean(dice_scores)),
        "Precision": float(np.mean(precisions)),
        "Recall": float(np.mean(recalls)),
        "F1 Score": float(np.mean(f1s)),
        "Pixel Accuracy": float(np.mean(pixel_accuracies)),
        "MAE": float(np.mean(mae_scores))
    }
    return metrics

# ========== 3. Run experiment and save results ==========
def run_experiment(model_class, model_name, learning_rate, batch_size, num_epochs, loss_function,
                   trainset, valset, device="cuda", output_dir="outputs/UNet"):
    os.makedirs(output_dir, exist_ok=True)
    trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=12)
    valloader = DataLoader(valset, batch_size=batch_size, shuffle=False, num_workers=1)
    model = model_class().to(device)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    model, train_losses, val_losses = train_and_validate(
        model=model,
        trainloader=trainloader,
        testloader=valloader,
        criterion=loss_function,
        optimizer=optimizer,
        num_epochs=num_epochs,
        device=device
    )

    metrics = evaluate_segmentation_model(model, valloader, device)
    model_save_path = os.path.join(output_dir, f"{model_name}_model.pt")
    torch.save(model.state_dict(), model_save_path)

    result = {
        "model_name": model_name,
        "learning_rate": learning_rate,
        "batch_size": batch_size,
        "num_epochs": num_epochs,
        "loss_function": loss_function.__class__.__name__,
        "train_losses": train_losses,
        "val_losses": val_losses,
        **metrics
    }

    return result, model_save_path

# ========== 4. Full grid search tuning function ==========
def tune_model(model_class, model_name, param_grid, loss_function_map, trainset, valset, device="cuda"):
    results = []
    grid = list(itertools.product(*param_grid.values()))
    keys = list(param_grid.keys())
    output_dir = os.path.join("outputs", model_name)
    os.makedirs(output_dir, exist_ok=True)

    for i, values in enumerate(grid, 1):
        params = dict(zip(keys, values))
        print(f"\nRunning configuration {i}/{len(grid)}: {params}")
        loss_function = loss_function_map[params["loss_function"]]
        exp_name = f"{model_name}_lr{params['learning_rate']}_bs{params['batch_size']}_ep{params['num_epochs']}_{params['loss_function']}"

        result, model_path = run_experiment(
            model_class=model_class,
            model_name=exp_name,
            learning_rate=params["learning_rate"],
            batch_size=params["batch_size"],
            num_epochs=params["num_epochs"],
            loss_function=loss_function,
            trainset=trainset,
            valset=valset,
            device=device,
            output_dir=output_dir
        )
        result["model_path"] = model_path
        results.append(result)

    result_path = os.path.join(output_dir, f"gridsearch_results.json")
    with open(result_path, "w") as f:
        json.dump(results, f, indent=4)

    return results

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import os
import math

# Function to load JSON summary and return dataframe
def load_experiment_summary(path, drop_losses=True):
    with open(path, "r") as f:
        data = json.load(f)

    df = pd.DataFrame(data)
    if drop_losses:
        df = df.drop(columns=["train_losses", "val_losses", "model_path"])
    return df

# Function to plot all loss curves in a grid layout (3 per row)
def plot_loss_curves_from_json_grid(path, columns=3):
    with open(path, "r") as f:
        experiments = json.load(f)

    total = len(experiments)
    rows = math.ceil(total / columns)

    fig, axes = plt.subplots(rows, columns, figsize=(6 * columns, 4 * rows))

    for i, exp in enumerate(experiments):
        row, col = divmod(i, columns)
        ax = axes[row][col] if rows > 1 else axes[col]

        name = exp["model_name"]
        train_losses = exp["train_losses"]
        val_losses = exp["val_losses"]

        ax.plot(train_losses, label="Train")
        ax.plot(val_losses, label="Val")
        ax.set_title(name)
        ax.set_xlabel("Epoch")
        ax.set_ylabel("Loss")
        ax.legend()
        ax.grid(True)

    # Hide any empty subplots
    for j in range(total, rows * columns):
        row, col = divmod(j, columns)
        ax = axes[row][col] if rows > 1 else axes[col]
        ax.axis("off")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## III. Model and training

# %% [markdown]
# ### III.1. TinyUNet

# %%
import torch.nn as nn

class Block(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.ReLU()
        )

    def forward(self, x):
        #print(f"Block: x.shape = {x.shape}, out_channels = {self.block[0].out_channels}")
        return self.block(x)
    
class Down(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = Block(in_channels, out_channels)
        self.down = nn.MaxPool2d(2)

    def forward(self, x):
        #print(f"Down: x.shape = {x.shape}")
        x = self.block(x)
        x_down = self.down(x)
        return x, x_down
    
class Up(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_channels, in_channels, kernel_size=2, stride=2)
        self.block = Block(in_channels + in_channels, out_channels)

    def forward(self, x, skip):
        #print(f"Up: x.shape = {x.shape}, skip.shape = {skip.shape}")
        x = self.up(x)
        x = torch.cat([x, skip], dim=1)  
        x = self.block(x)
        return x

class TinyUnet(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels

        self.down1 = Down(in_channels, 64)
        self.down2 = Down(64, 128)
        self.down3 = Down(128, 256)
        self.middle = Block(256, 256)
        self.up3 = Up(256, 128)
        self.up2 = Up(128, 64)
        self.up1 = Up(64, 32)
        self.conv = nn.Conv2d(32, out_channels, kernel_size=1)

    def forward(self, x):
        # x is (B, in_channels, H, W)
        x1, x = self.down1(x)  # x1 is (B, 64, H, W), x is (B, 64, H/2, W/2)
        x2, x = self.down2(x)  # x2 is (B, 128, H/2, W/2), x is (B, 128, H/4, W/4)
        x3, x = self.down3(x)  # x3 is (B, 256, H/4, W/4), x is (B, 256, H/8, W/8)
        x = self.middle(x)     # x is (B, 256, H/8, W/8)
        x = self.up3(x, x3)    # x is (B, 128, H/4, W/4)
        x = self.up2(x, x2)    # x is (B, 64, H/2, W/2)
        x = self.up1(x, x1)    # x is (B, 32, H, W)
        x = self.conv(x)       # x is (B, out_channels, H, W)
        return x

# %%
from torch import nn

param_grid = {
    "learning_rate": [1e-5, 1e-4, 1e-3],
    "batch_size": [4, 8],
    "num_epochs": [20, 40],
    "loss_function": ["BCEWithLogitsLoss"]
}

loss_function_map = {
    "BCEWithLogitsLoss": nn.BCEWithLogitsLoss(),
}

results_tinyunet = tune_model(
    model_class=lambda: TinyUnet(in_channels=3, out_channels=1),
    model_name="TinyUNet-5",
    param_grid=param_grid,
    loss_function_map=loss_function_map,
    trainset=trainset,
    valset=valset,
    device=device
)
# Out:
# Running configuration 1/12: {'learning_rate': 1e-05, 'batch_size': 4, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.6734 | Val Loss: 0.6712
#
# Epoch 2/20
# Train Loss: 0.6683 | Val Loss: 0.6664
#
# Epoch 3/20
# Train Loss: 0.6622 | Val Loss: 0.6600
#
# Epoch 4/20
# Train Loss: 0.6539 | Val Loss: 0.6510
#
# Epoch 5/20
# Train Loss: 0.6416 | Val Loss: 0.6377
#
# Epoch 6/20
# Train Loss: 0.6238 | Val Loss: 0.6164
#
# Epoch 7/20
# Train Loss: 0.5883 | Val Loss: 0.5624
#
# Epoch 8/20
# Train Loss: 0.4500 | Val Loss: 0.2919
#
# Epoch 9/20
# Train Loss: 0.1721 | Val Loss: 0.1359
#
# Epoch 10/20
# Train Loss: 0.1317 | Val Loss: 0.1264
#
# Epoch 11/20
# Train Loss: 0.1244 | Val Loss: 0.1176
#
# Epoch 12/20
# Train Loss: 0.1219 | Val Loss: 0.1154
#
# Epoch 13/20
# Train Loss: 0.1193 | Val Loss: 0.1128
#
# Epoch 14/20
# Train Loss: 0.1162 | Val Loss: 0.1113
#
# Epoch 15/20
# Train Loss: 0.1146 | Val Loss: 0.1094
#
# Epoch 16/20
# Train Loss: 0.1146 | Val Loss: 0.1064
#
# Epoch 17/20
# Train Loss: 0.1125 | Val Loss: 0.1052
#
# Epoch 18/20
# Train Loss: 0.1109 | Val Loss: 0.1045
#
# Epoch 19/20
# Train Loss: 0.1097 | Val Loss: 0.1024
#
# Epoch 20/20
# Train Loss: 0.1100 | Val Loss: 0.1007
#
# Running configuration 2/12: {'learning_rate': 1e-05, 'batch_size': 4, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.7492 | Val Loss: 0.7481
#
# Epoch 2/40
# Train Loss: 0.7431 | Val Loss: 0.7421
#
# Epoch 3/40
# Train Loss: 0.7349 | Val Loss: 0.7341
#
# Epoch 4/40
# Train Loss: 0.7251 | Val Loss: 0.7229
#
# Epoch 5/40
# Train Loss: 0.7112 | Val Loss: 0.7076
#
# Epoch 6/40
# Train Loss: 0.6884 | Val Loss: 0.6812
#
# Epoch 7/40
# Train Loss: 0.6414 | Val Loss: 0.5988
#
# Epoch 8/40
# Train Loss: 0.4214 | Val Loss: 0.2089
#
# Epoch 9/40
# Train Loss: 0.1409 | Val Loss: 0.1301
#
# Epoch 10/40
# Train Loss: 0.1288 | Val Loss: 0.1294
#
# Epoch 11/40
# Train Loss: 0.1209 | Val Loss: 0.1200
#
# Epoch 12/40
# Train Loss: 0.1206 | Val Loss: 0.1183
#
# Epoch 13/40
# Train Loss: 0.1189 | Val Loss: 0.1147
#
# Epoch 14/40
# Train Loss: 0.1179 | Val Loss: 0.1119
#
# Epoch 15/40
# Train Loss: 0.1156 | Val Loss: 0.1115
#
# Epoch 16/40
# Train Loss: 0.1158 | Val Loss: 0.1084
#
# Epoch 17/40
# Train Loss: 0.1119 | Val Loss: 0.1090
#
# Epoch 18/40
# Train Loss: 0.1112 | Val Loss: 0.1049
#
# Epoch 19/40
# Train Loss: 0.1103 | Val Loss: 0.1035
#
# Epoch 20/40
# Train Loss: 0.1085 | Val Loss: 0.1027
#
# Epoch 21/40
# Train Loss: 0.1087 | Val Loss: 0.1003
#
# Epoch 22/40
# Train Loss: 0.1077 | Val Loss: 0.0984
#
# Epoch 23/40
# Train Loss: 0.1081 | Val Loss: 0.0973
#
# Epoch 24/40
# Train Loss: 0.1048 | Val Loss: 0.0964
#
# Epoch 25/40
# Train Loss: 0.1034 | Val Loss: 0.0950
#
# Epoch 26/40
# Train Loss: 0.1027 | Val Loss: 0.0938
#
# Epoch 27/40
# Train Loss: 0.1013 | Val Loss: 0.0935
#
# Epoch 28/40
# Train Loss: 0.1014 | Val Loss: 0.0935
#
# Epoch 29/40
# Train Loss: 0.0985 | Val Loss: 0.0921
#
# Epoch 30/40
# Train Loss: 0.1002 | Val Loss: 0.0904
#
# Epoch 31/40
# Train Loss: 0.0978 | Val Loss: 0.0916
#
# Epoch 32/40
# Train Loss: 0.0985 | Val Loss: 0.0894
#
# Epoch 33/40
# Train Loss: 0.0983 | Val Loss: 0.0891
#
# Epoch 34/40
# Train Loss: 0.0967 | Val Loss: 0.0874
#
# Epoch 35/40
# Train Loss: 0.0958 | Val Loss: 0.0869
#
# Epoch 36/40
# Train Loss: 0.0946 | Val Loss: 0.0860
#
# Epoch 37/40
# Train Loss: 0.0959 | Val Loss: 0.0870
#
# Epoch 38/40
# Train Loss: 0.0931 | Val Loss: 0.0855
#
# Epoch 39/40
# Train Loss: 0.0920 | Val Loss: 0.0843
#
# Epoch 40/40
# Train Loss: 0.0927 | Val Loss: 0.0836
#
# Running configuration 3/12: {'learning_rate': 1e-05, 'batch_size': 8, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.7024 | Val Loss: 0.7020
#
# Epoch 2/20
# Train Loss: 0.7013 | Val Loss: 0.7009
#
# Epoch 3/20
# Train Loss: 0.7000 | Val Loss: 0.6998
#
# Epoch 4/20
# Train Loss: 0.6987 | Val Loss: 0.6985
#
# Epoch 5/20
# Train Loss: 0.6971 | Val Loss: 0.6969
#
# Epoch 6/20
# Train Loss: 0.6950 | Val Loss: 0.6948
#
# Epoch 7/20
# Train Loss: 0.6925 | Val Loss: 0.6922
#
# Epoch 8/20
# Train Loss: 0.6894 | Val Loss: 0.6889
#
# Epoch 9/20
# Train Loss: 0.6851 | Val Loss: 0.6846
#
# Epoch 10/20
# Train Loss: 0.6802 | Val Loss: 0.6791
#
# Epoch 11/20
# Train Loss: 0.6729 | Val Loss: 0.6715
#
# Epoch 12/20
# Train Loss: 0.6634 | Val Loss: 0.6593
#
# Epoch 13/20
# Train Loss: 0.6450 | Val Loss: 0.6354
#
# Epoch 14/20
# Train Loss: 0.6026 | Val Loss: 0.5768
#
# Epoch 15/20
# Train Loss: 0.5013 | Val Loss: 0.4279
#
# Epoch 16/20
# Train Loss: 0.3007 | Val Loss: 0.1961
#
# Epoch 17/20
# Train Loss: 0.1492 | Val Loss: 0.1409
#
# Epoch 18/20
# Train Loss: 0.1610 | Val Loss: 0.1358
#
# Epoch 19/20
# Train Loss: 0.1402 | Val Loss: 0.1320
#
# Epoch 20/20
# Train Loss: 0.1346 | Val Loss: 0.1333
#
# Running configuration 4/12: {'learning_rate': 1e-05, 'batch_size': 8, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.6648 | Val Loss: 0.6637
#
# Epoch 2/40
# Train Loss: 0.6623 | Val Loss: 0.6613
#
# Epoch 3/40
# Train Loss: 0.6591 | Val Loss: 0.6586
#
# Epoch 4/40
# Train Loss: 0.6565 | Val Loss: 0.6555
#
# Epoch 5/40
# Train Loss: 0.6529 | Val Loss: 0.6519
#
# Epoch 6/40
# Train Loss: 0.6489 | Val Loss: 0.6476
#
# Epoch 7/40
# Train Loss: 0.6439 | Val Loss: 0.6427
#
# Epoch 8/40
# Train Loss: 0.6375 | Val Loss: 0.6368
#
# Epoch 9/40
# Train Loss: 0.6306 | Val Loss: 0.6297
#
# Epoch 10/40
# Train Loss: 0.6244 | Val Loss: 0.6212
#
# Epoch 11/40
# Train Loss: 0.6113 | Val Loss: 0.6100
#
# Epoch 12/40
# Train Loss: 0.5992 | Val Loss: 0.5944
#
# Epoch 13/40
# Train Loss: 0.5787 | Val Loss: 0.5687
#
# Epoch 14/40
# Train Loss: 0.5354 | Val Loss: 0.5162
#
# Epoch 15/40
# Train Loss: 0.4563 | Val Loss: 0.3929
#
# Epoch 16/40
# Train Loss: 0.2817 | Val Loss: 0.1871
#
# Epoch 17/40
# Train Loss: 0.1466 | Val Loss: 0.1271
#
# Epoch 18/40
# Train Loss: 0.1478 | Val Loss: 0.1260
#
# Epoch 19/40
# Train Loss: 0.1346 | Val Loss: 0.1218
#
# Epoch 20/40
# Train Loss: 0.1287 | Val Loss: 0.1235
#
# Epoch 21/40
# Train Loss: 0.1281 | Val Loss: 0.1185
#
# Epoch 22/40
# Train Loss: 0.1205 | Val Loss: 0.1151
#
# Epoch 23/40
# Train Loss: 0.1245 | Val Loss: 0.1148
#
# Epoch 24/40
# Train Loss: 0.1234 | Val Loss: 0.1145
#
# Epoch 25/40
# Train Loss: 0.1191 | Val Loss: 0.1113
#
# Epoch 26/40
# Train Loss: 0.1196 | Val Loss: 0.1098
#
# Epoch 27/40
# Train Loss: 0.1153 | Val Loss: 0.1092
#
# Epoch 28/40
# Train Loss: 0.1176 | Val Loss: 0.1075
#
# Epoch 29/40
# Train Loss: 0.1138 | Val Loss: 0.1064
#
# Epoch 30/40
# Train Loss: 0.1139 | Val Loss: 0.1056
#
# Epoch 31/40
# Train Loss: 0.1137 | Val Loss: 0.1044
#
# Epoch 32/40
# Train Loss: 0.1115 | Val Loss: 0.1034
#
# Epoch 33/40
# Train Loss: 0.1107 | Val Loss: 0.1032
#
# Epoch 34/40
# Train Loss: 0.1115 | Val Loss: 0.1014
#
# Epoch 35/40
# Train Loss: 0.1097 | Val Loss: 0.1009
#
# Epoch 36/40
# Train Loss: 0.1068 | Val Loss: 0.1004
#
# Epoch 37/40
# Train Loss: 0.1074 | Val Loss: 0.0990
#
# Epoch 38/40
# Train Loss: 0.1079 | Val Loss: 0.0981
#
# Epoch 39/40
# Train Loss: 0.1066 | Val Loss: 0.0975
#
# Epoch 40/40
# Train Loss: 0.1061 | Val Loss: 0.0961
#
# Running configuration 5/12: {'learning_rate': 0.0001, 'batch_size': 4, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.7352 | Val Loss: 0.7123
#
# Epoch 2/20
# Train Loss: 0.4975 | Val Loss: 0.2241
#
# Epoch 3/20
# Train Loss: 0.1625 | Val Loss: 0.1252
#
# Epoch 4/20
# Train Loss: 0.1190 | Val Loss: 0.1006
#
# Epoch 5/20
# Train Loss: 0.1064 | Val Loss: 0.0940
#
# Epoch 6/20
# Train Loss: 0.1025 | Val Loss: 0.0919
#
# Epoch 7/20
# Train Loss: 0.0996 | Val Loss: 0.0875
#
# Epoch 8/20
# Train Loss: 0.0948 | Val Loss: 0.0839
#
# Epoch 9/20
# Train Loss: 0.0920 | Val Loss: 0.0806
#
# Epoch 10/20
# Train Loss: 0.0865 | Val Loss: 0.0753
#
# Epoch 11/20
# Train Loss: 0.0836 | Val Loss: 0.0661
#
# Epoch 12/20
# Train Loss: 0.0709 | Val Loss: 0.0549
#
# Epoch 13/20
# Train Loss: 0.0584 | Val Loss: 0.0441
#
# Epoch 14/20
# Train Loss: 0.0457 | Val Loss: 0.0367
#
# Epoch 15/20
# Train Loss: 0.0412 | Val Loss: 0.0337
#
# Epoch 16/20
# Train Loss: 0.0384 | Val Loss: 0.0318
#
# Epoch 17/20
# Train Loss: 0.0365 | Val Loss: 0.0314
#
# Epoch 18/20
# Train Loss: 0.0334 | Val Loss: 0.0305
#
# Epoch 19/20
# Train Loss: 0.0315 | Val Loss: 0.0279
#
# Epoch 20/20
# Train Loss: 0.0299 | Val Loss: 0.0274
#
# Running configuration 6/12: {'learning_rate': 0.0001, 'batch_size': 4, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.6650 | Val Loss: 0.6134
#
# Epoch 2/40
# Train Loss: 0.3579 | Val Loss: 0.1285
#
# Epoch 3/40
# Train Loss: 0.1243 | Val Loss: 0.1081
#
# Epoch 4/40
# Train Loss: 0.1112 | Val Loss: 0.0982
#
# Epoch 5/40
# Train Loss: 0.1035 | Val Loss: 0.0919
#
# Epoch 6/40
# Train Loss: 0.0987 | Val Loss: 0.0884
#
# Epoch 7/40
# Train Loss: 0.0982 | Val Loss: 0.0859
#
# Epoch 8/40
# Train Loss: 0.0945 | Val Loss: 0.0886
#
# Epoch 9/40
# Train Loss: 0.0950 | Val Loss: 0.0803
#
# Epoch 10/40
# Train Loss: 0.0867 | Val Loss: 0.0764
#
# Epoch 11/40
# Train Loss: 0.0861 | Val Loss: 0.0717
#
# Epoch 12/40
# Train Loss: 0.0777 | Val Loss: 0.0652
#
# Epoch 13/40
# Train Loss: 0.0717 | Val Loss: 0.0574
#
# Epoch 14/40
# Train Loss: 0.0621 | Val Loss: 0.0481
#
# Epoch 15/40
# Train Loss: 0.0518 | Val Loss: 0.0427
#
# Epoch 16/40
# Train Loss: 0.0443 | Val Loss: 0.0360
#
# Epoch 17/40
# Train Loss: 0.0394 | Val Loss: 0.0315
#
# Epoch 18/40
# Train Loss: 0.0367 | Val Loss: 0.0318
#
# Epoch 19/40
# Train Loss: 0.0339 | Val Loss: 0.0289
#
# Epoch 20/40
# Train Loss: 0.0305 | Val Loss: 0.0263
#
# Epoch 21/40
# Train Loss: 0.0295 | Val Loss: 0.0270
#
# Epoch 22/40
# Train Loss: 0.0292 | Val Loss: 0.0252
#
# Epoch 23/40
# Train Loss: 0.0282 | Val Loss: 0.0245
#
# Epoch 24/40
# Train Loss: 0.0274 | Val Loss: 0.0238
#
# Epoch 25/40
# Train Loss: 0.0268 | Val Loss: 0.0254
#
# Epoch 26/40
# Train Loss: 0.0258 | Val Loss: 0.0230
#
# Epoch 27/40
# Train Loss: 0.0256 | Val Loss: 0.0225
#
# Epoch 28/40
# Train Loss: 0.0246 | Val Loss: 0.0217
#
# Epoch 29/40
# Train Loss: 0.0236 | Val Loss: 0.0215
#
# Epoch 30/40
# Train Loss: 0.0224 | Val Loss: 0.0212
#
# Epoch 31/40
# Train Loss: 0.0222 | Val Loss: 0.0212
#
# Epoch 32/40
# Train Loss: 0.0224 | Val Loss: 0.0209
#
# Epoch 33/40
# Train Loss: 0.0218 | Val Loss: 0.0198
#
# Epoch 34/40
# Train Loss: 0.0214 | Val Loss: 0.0204
#
# Epoch 35/40
# Train Loss: 0.0208 | Val Loss: 0.0195
#
# Epoch 36/40
# Train Loss: 0.0202 | Val Loss: 0.0189
#
# Epoch 37/40
# Train Loss: 0.0200 | Val Loss: 0.0186
#
# Epoch 38/40
# Train Loss: 0.0193 | Val Loss: 0.0180
#
# Epoch 39/40
# Train Loss: 0.0194 | Val Loss: 0.0181
#
# Epoch 40/40
# Train Loss: 0.0186 | Val Loss: 0.0173
#
# Running configuration 7/12: {'learning_rate': 0.0001, 'batch_size': 8, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.6384 | Val Loss: 0.6249
#
# Epoch 2/20
# Train Loss: 0.5974 | Val Loss: 0.5677
#
# Epoch 3/20
# Train Loss: 0.4773 | Val Loss: 0.3183
#
# Epoch 4/20
# Train Loss: 0.1879 | Val Loss: 0.1247
#
# Epoch 5/20
# Train Loss: 0.1339 | Val Loss: 0.1411
#
# Epoch 6/20
# Train Loss: 0.1170 | Val Loss: 0.1081
#
# Epoch 7/20
# Train Loss: 0.1129 | Val Loss: 0.1050
#
# Epoch 8/20
# Train Loss: 0.1074 | Val Loss: 0.0963
#
# Epoch 9/20
# Train Loss: 0.1027 | Val Loss: 0.0922
#
# Epoch 10/20
# Train Loss: 0.0990 | Val Loss: 0.0892
#
# Epoch 11/20
# Train Loss: 0.0969 | Val Loss: 0.0863
#
# Epoch 12/20
# Train Loss: 0.0940 | Val Loss: 0.0844
#
# Epoch 13/20
# Train Loss: 0.0933 | Val Loss: 0.0823
#
# Epoch 14/20
# Train Loss: 0.0910 | Val Loss: 0.0804
#
# Epoch 15/20
# Train Loss: 0.0882 | Val Loss: 0.0778
#
# Epoch 16/20
# Train Loss: 0.0866 | Val Loss: 0.0750
#
# Epoch 17/20
# Train Loss: 0.0827 | Val Loss: 0.0720
#
# Epoch 18/20
# Train Loss: 0.0809 | Val Loss: 0.0688
#
# Epoch 19/20
# Train Loss: 0.0750 | Val Loss: 0.0636
#
# Epoch 20/20
# Train Loss: 0.0708 | Val Loss: 0.0596
#
# Running configuration 8/12: {'learning_rate': 0.0001, 'batch_size': 8, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.7453 | Val Loss: 0.7269
#
# Epoch 2/40
# Train Loss: 0.6930 | Val Loss: 0.6426
#
# Epoch 3/40
# Train Loss: 0.4541 | Val Loss: 0.1265
#
# Epoch 4/40
# Train Loss: 0.1730 | Val Loss: 0.1186
#
# Epoch 5/40
# Train Loss: 0.1328 | Val Loss: 0.1185
#
# Epoch 6/40
# Train Loss: 0.1218 | Val Loss: 0.1045
#
# Epoch 7/40
# Train Loss: 0.1125 | Val Loss: 0.1062
#
# Epoch 8/40
# Train Loss: 0.1062 | Val Loss: 0.0958
#
# Epoch 9/40
# Train Loss: 0.1022 | Val Loss: 0.0970
#
# Epoch 10/40
# Train Loss: 0.1003 | Val Loss: 0.0907
#
# Epoch 11/40
# Train Loss: 0.1001 | Val Loss: 0.0893
#
# Epoch 12/40
# Train Loss: 0.0993 | Val Loss: 0.0872
#
# Epoch 13/40
# Train Loss: 0.0953 | Val Loss: 0.0859
#
# Epoch 14/40
# Train Loss: 0.0951 | Val Loss: 0.0835
#
# Epoch 15/40
# Train Loss: 0.0932 | Val Loss: 0.0816
#
# Epoch 16/40
# Train Loss: 0.0894 | Val Loss: 0.0782
#
# Epoch 17/40
# Train Loss: 0.0862 | Val Loss: 0.0749
#
# Epoch 18/40
# Train Loss: 0.0828 | Val Loss: 0.0710
#
# Epoch 19/40
# Train Loss: 0.0791 | Val Loss: 0.0667
#
# Epoch 20/40
# Train Loss: 0.0745 | Val Loss: 0.0611
#
# Epoch 21/40
# Train Loss: 0.0678 | Val Loss: 0.0551
#
# Epoch 22/40
# Train Loss: 0.0616 | Val Loss: 0.0489
#
# Epoch 23/40
# Train Loss: 0.0553 | Val Loss: 0.0435
#
# Epoch 24/40
# Train Loss: 0.0490 | Val Loss: 0.0391
#
# Epoch 25/40
# Train Loss: 0.0440 | Val Loss: 0.0368
#
# Epoch 26/40
# Train Loss: 0.0406 | Val Loss: 0.0339
#
# Epoch 27/40
# Train Loss: 0.0399 | Val Loss: 0.0353
#
# Epoch 28/40
# Train Loss: 0.0386 | Val Loss: 0.0317
#
# Epoch 29/40
# Train Loss: 0.0372 | Val Loss: 0.0336
#
# Epoch 30/40
# Train Loss: 0.0364 | Val Loss: 0.0303
#
# Epoch 31/40
# Train Loss: 0.0338 | Val Loss: 0.0295
#
# Epoch 32/40
# Train Loss: 0.0320 | Val Loss: 0.0279
#
# Epoch 33/40
# Train Loss: 0.0306 | Val Loss: 0.0279
#
# Epoch 34/40
# Train Loss: 0.0303 | Val Loss: 0.0266
#
# Epoch 35/40
# Train Loss: 0.0295 | Val Loss: 0.0264
#
# Epoch 36/40
# Train Loss: 0.0294 | Val Loss: 0.0258
#
# Epoch 37/40
# Train Loss: 0.0287 | Val Loss: 0.0260
#
# Epoch 38/40
# Train Loss: 0.0282 | Val Loss: 0.0248
#
# Epoch 39/40
# Train Loss: 0.0277 | Val Loss: 0.0248
#
# Epoch 40/40
# Train Loss: 0.0271 | Val Loss: 0.0239
#
# Running configuration 9/12: {'learning_rate': 0.001, 'batch_size': 4, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.2798 | Val Loss: 0.0930
#
# Epoch 2/20
# Train Loss: 0.0862 | Val Loss: 0.0677
#
# Epoch 3/20
# Train Loss: 0.0660 | Val Loss: 0.0432
#
# Epoch 4/20
# Train Loss: 0.0438 | Val Loss: 0.0318
#
# Epoch 5/20
# Train Loss: 0.0384 | Val Loss: 0.0313
#
# Epoch 6/20
# Train Loss: 0.0341 | Val Loss: 0.0291
#
# Epoch 7/20
# Train Loss: 0.0326 | Val Loss: 0.0286
#
# Epoch 8/20
# Train Loss: 0.0307 | Val Loss: 0.0266
#
# Epoch 9/20
# Train Loss: 0.0290 | Val Loss: 0.0251
#
# Epoch 10/20
# Train Loss: 0.0269 | Val Loss: 0.0213
#
# Epoch 11/20
# Train Loss: 0.0232 | Val Loss: 0.0244
#
# Epoch 12/20
# Train Loss: 0.0227 | Val Loss: 0.0191
#
# Epoch 13/20
# Train Loss: 0.0205 | Val Loss: 0.0180
#
# Epoch 14/20
# Train Loss: 0.0192 | Val Loss: 0.0174
#
# Epoch 15/20
# Train Loss: 0.0183 | Val Loss: 0.0173
#
# Epoch 16/20
# Train Loss: 0.0172 | Val Loss: 0.0158
#
# Epoch 17/20
# Train Loss: 0.0183 | Val Loss: 0.0169
#
# Epoch 18/20
# Train Loss: 0.0168 | Val Loss: 0.0156
#
# Epoch 19/20
# Train Loss: 0.0152 | Val Loss: 0.0136
#
# Epoch 20/20
# Train Loss: 0.0144 | Val Loss: 0.0132
#
# Running configuration 10/12: {'learning_rate': 0.001, 'batch_size': 4, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.2474 | Val Loss: 0.0941
#
# Epoch 2/40
# Train Loss: 0.0866 | Val Loss: 0.0681
#
# Epoch 3/40
# Train Loss: 0.0728 | Val Loss: 0.0553
#
# Epoch 4/40
# Train Loss: 0.0572 | Val Loss: 0.0462
#
# Epoch 5/40
# Train Loss: 0.0467 | Val Loss: 0.0366
#
# Epoch 6/40
# Train Loss: 0.0388 | Val Loss: 0.0343
#
# Epoch 7/40
# Train Loss: 0.0380 | Val Loss: 0.0301
#
# Epoch 8/40
# Train Loss: 0.0343 | Val Loss: 0.0274
#
# Epoch 9/40
# Train Loss: 0.0282 | Val Loss: 0.0245
#
# Epoch 10/40
# Train Loss: 0.0313 | Val Loss: 0.0260
#
# Epoch 11/40
# Train Loss: 0.0299 | Val Loss: 0.0224
#
# Epoch 12/40
# Train Loss: 0.0246 | Val Loss: 0.0218
#
# Epoch 13/40
# Train Loss: 0.0240 | Val Loss: 0.0218
#
# Epoch 14/40
# Train Loss: 0.0231 | Val Loss: 0.0208
#
# Epoch 15/40
# Train Loss: 0.0216 | Val Loss: 0.0188
#
# Epoch 16/40
# Train Loss: 0.0206 | Val Loss: 0.0182
#
# Epoch 17/40
# Train Loss: 0.0197 | Val Loss: 0.0180
#
# Epoch 18/40
# Train Loss: 0.0184 | Val Loss: 0.0162
#
# Epoch 19/40
# Train Loss: 0.0183 | Val Loss: 0.0155
#
# Epoch 20/40
# Train Loss: 0.0177 | Val Loss: 0.0152
#
# Epoch 21/40
# Train Loss: 0.0162 | Val Loss: 0.0144
#
# Epoch 22/40
# Train Loss: 0.0158 | Val Loss: 0.0133
#
# Epoch 23/40
# Train Loss: 0.0144 | Val Loss: 0.0131
#
# Epoch 24/40
# Train Loss: 0.0141 | Val Loss: 0.0138
#
# Epoch 25/40
# Train Loss: 0.0145 | Val Loss: 0.0126
#
# Epoch 26/40
# Train Loss: 0.0130 | Val Loss: 0.0127
#
# Epoch 27/40
# Train Loss: 0.0129 | Val Loss: 0.0121
#
# Epoch 28/40
# Train Loss: 0.0123 | Val Loss: 0.0115
#
# Epoch 29/40
# Train Loss: 0.0125 | Val Loss: 0.0119
#
# Epoch 30/40
# Train Loss: 0.0125 | Val Loss: 0.0114
#
# Epoch 31/40
# Train Loss: 0.0121 | Val Loss: 0.0108
#
# Epoch 32/40
# Train Loss: 0.0116 | Val Loss: 0.0100
#
# Epoch 33/40
# Train Loss: 0.0114 | Val Loss: 0.0097
#
# Epoch 34/40
# Train Loss: 0.0109 | Val Loss: 0.0102
#
# Epoch 35/40
# Train Loss: 0.0102 | Val Loss: 0.0094
#
# Epoch 36/40
# Train Loss: 0.0099 | Val Loss: 0.0092
#
# Epoch 37/40
# Train Loss: 0.0097 | Val Loss: 0.0093
#
# Epoch 38/40
# Train Loss: 0.0100 | Val Loss: 0.0089
#
# Epoch 39/40
# Train Loss: 0.0098 | Val Loss: 0.0091
#
# Epoch 40/40
# Train Loss: 0.0094 | Val Loss: 0.0088
#
# Running configuration 11/12: {'learning_rate': 0.001, 'batch_size': 8, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.4106 | Val Loss: 0.1386
#
# Epoch 2/20
# Train Loss: 0.1078 | Val Loss: 0.0794
#
# Epoch 3/20
# Train Loss: 0.0828 | Val Loss: 0.0714
#
# Epoch 4/20
# Train Loss: 0.0769 | Val Loss: 0.0637
#
# Epoch 5/20
# Train Loss: 0.0692 | Val Loss: 0.0530
#
# Epoch 6/20
# Train Loss: 0.0611 | Val Loss: 0.0444
#
# Epoch 7/20
# Train Loss: 0.0509 | Val Loss: 0.0394
#
# Epoch 8/20
# Train Loss: 0.0461 | Val Loss: 0.0375
#
# Epoch 9/20
# Train Loss: 0.0396 | Val Loss: 0.0335
#
# Epoch 10/20
# Train Loss: 0.0363 | Val Loss: 0.0321
#
# Epoch 11/20
# Train Loss: 0.0338 | Val Loss: 0.0296
#
# Epoch 12/20
# Train Loss: 0.0315 | Val Loss: 0.0261
#
# Epoch 13/20
# Train Loss: 0.0290 | Val Loss: 0.0238
#
# Epoch 14/20
# Train Loss: 0.0269 | Val Loss: 0.0244
#
# Epoch 15/20
# Train Loss: 0.0261 | Val Loss: 0.0226
#
# Epoch 16/20
# Train Loss: 0.0257 | Val Loss: 0.0219
#
# Epoch 17/20
# Train Loss: 0.0243 | Val Loss: 0.0209
#
# Epoch 18/20
# Train Loss: 0.0243 | Val Loss: 0.0214
#
# Epoch 19/20
# Train Loss: 0.0238 | Val Loss: 0.0217
#
# Epoch 20/20
# Train Loss: 0.0228 | Val Loss: 0.0198
#
# Running configuration 12/12: {'learning_rate': 0.001, 'batch_size': 8, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.4675 | Val Loss: 0.2399
#
# Epoch 2/40
# Train Loss: 0.1473 | Val Loss: 0.0874
#
# Epoch 3/40
# Train Loss: 0.0958 | Val Loss: 0.0763
#
# Epoch 4/40
# Train Loss: 0.0837 | Val Loss: 0.0699
#
# Epoch 5/40
# Train Loss: 0.0781 | Val Loss: 0.0633
#
# Epoch 6/40
# Train Loss: 0.0709 | Val Loss: 0.0551
#
# Epoch 7/40
# Train Loss: 0.0593 | Val Loss: 0.0439
#
# Epoch 8/40
# Train Loss: 0.0524 | Val Loss: 0.0403
#
# Epoch 9/40
# Train Loss: 0.0458 | Val Loss: 0.0345
#
# Epoch 10/40
# Train Loss: 0.0434 | Val Loss: 0.0402
#
# Epoch 11/40
# Train Loss: 0.0435 | Val Loss: 0.0370
#
# Epoch 12/40
# Train Loss: 0.0402 | Val Loss: 0.0350
#
# Epoch 13/40
# Train Loss: 0.0385 | Val Loss: 0.0319
#
# Epoch 14/40
# Train Loss: 0.0348 | Val Loss: 0.0302
#
# Epoch 15/40
# Train Loss: 0.0358 | Val Loss: 0.0323
#
# Epoch 16/40
# Train Loss: 0.0341 | Val Loss: 0.0266
#
# Epoch 17/40
# Train Loss: 0.0296 | Val Loss: 0.0257
#
# Epoch 18/40
# Train Loss: 0.0275 | Val Loss: 0.0239
#
# Epoch 19/40
# Train Loss: 0.0277 | Val Loss: 0.0240
#
# Epoch 20/40
# Train Loss: 0.0268 | Val Loss: 0.0231
#
# Epoch 21/40
# Train Loss: 0.0255 | Val Loss: 0.0225
#
# Epoch 22/40
# Train Loss: 0.0247 | Val Loss: 0.0220
#
# Epoch 23/40
# Train Loss: 0.0237 | Val Loss: 0.0219
#
# Epoch 24/40
# Train Loss: 0.0241 | Val Loss: 0.0209
#
# Epoch 25/40
# Train Loss: 0.0231 | Val Loss: 0.0215
#
# Epoch 26/40
# Train Loss: 0.0216 | Val Loss: 0.0202
#
# Epoch 27/40
# Train Loss: 0.0221 | Val Loss: 0.0201
#
# Epoch 28/40
# Train Loss: 0.0218 | Val Loss: 0.0210
#
# Epoch 29/40
# Train Loss: 0.0216 | Val Loss: 0.0191
#
# Epoch 30/40
# Train Loss: 0.0200 | Val Loss: 0.0179
#
# Epoch 31/40
# Train Loss: 0.0193 | Val Loss: 0.0179
#
# Epoch 32/40
# Train Loss: 0.0184 | Val Loss: 0.0165
#
# Epoch 33/40
# Train Loss: 0.0173 | Val Loss: 0.0167
#
# Epoch 34/40
# Train Loss: 0.0174 | Val Loss: 0.0163
#
# Epoch 35/40
# Train Loss: 0.0169 | Val Loss: 0.0157
#
# Epoch 36/40
# Train Loss: 0.0170 | Val Loss: 0.0150
#
# Epoch 37/40
# Train Loss: 0.0160 | Val Loss: 0.0144
#
# Epoch 38/40
# Train Loss: 0.0157 | Val Loss: 0.0137
#
# Epoch 39/40
# Train Loss: 0.0149 | Val Loss: 0.0130
#
# Epoch 40/40
# Train Loss: 0.0144 | Val Loss: 0.0128

# %% [markdown]
# ### III.2. UNet

# %%
import torch
import torch.nn as nn

class Block(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.block(x)

class Down(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = Block(in_channels, out_channels)
        self.down = nn.MaxPool2d(2)

    def forward(self, x):
        x = self.block(x)
        x_down = self.down(x)
        return x, x_down

class Up(nn.Module):
    def __init__(self, up_in_channels, skip_in_channels, out_channels):
        super().__init__()
        self.up = nn.ConvTranspose2d(up_in_channels, skip_in_channels, kernel_size=2, stride=2)
        self.block = Block(skip_in_channels + skip_in_channels, out_channels)

    def forward(self, x, skip):
        x = self.up(x)
        diffY = skip.size()[2] - x.size()[2]
        diffX = skip.size()[3] - x.size()[3]
        x = nn.functional.pad(x, [diffX // 2, diffX - diffX // 2,
                                  diffY // 2, diffY - diffY // 2])
        x = torch.cat([x, skip], dim=1)
        return self.block(x)

class UNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=1):
        super().__init__()

        self.down1 = Down(in_channels, 64)
        self.down2 = Down(64, 128)
        self.down3 = Down(128, 256)
        self.down4 = Down(256, 512)

        self.middle = Block(512, 1024)

        self.up4 = Up(1024, 512, 512)
        self.up3 = Up(512, 256, 256)
        self.up2 = Up(256, 128, 128)
        self.up1 = Up(128, 64, 64)

        self.final_conv = nn.Conv2d(64, out_channels, kernel_size=1)

    def forward(self, x):
        x1, x = self.down1(x)  # x1: 64
        x2, x = self.down2(x)  # x2: 128
        x3, x = self.down3(x)  # x3: 256
        x4, x = self.down4(x)  # x4: 512

        x = self.middle(x)     # 1024

        x = self.up4(x, x4)    # (1024 → 512) + 512 = 1024 → 512
        x = self.up3(x, x3)    # (512 → 256) + 256 = 512 → 256
        x = self.up2(x, x2)    # (256 → 128) + 128 = 256 → 128
        x = self.up1(x, x1)    # (128 → 64) + 64 = 128 → 64

        return self.final_conv(x)

# %%
from torch import nn

param_grid = {
    "learning_rate": [1e-5, 1e-4, 1e-3],
    "batch_size": [4, 8],
    "num_epochs": [20, 40],
    # "num_epochs": [1],
    "loss_function": ["BCEWithLogitsLoss"]
}

loss_function_map = {
    "BCEWithLogitsLoss": nn.BCEWithLogitsLoss(),
}


results_unet = tune_model(
    model_class=lambda: UNet(in_channels=3, out_channels=1),
    model_name="UNet-5",
    param_grid=param_grid,
    loss_function_map=loss_function_map,
    trainset=trainset,
    valset=valset,
    device=device
)
# Out:
# Running configuration 1/12: {'learning_rate': 1e-05, 'batch_size': 4, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.7230 | Val Loss: 0.7210
#
# Epoch 2/20
# Train Loss: 0.7190 | Val Loss: 0.7167
#
# Epoch 3/20
# Train Loss: 0.7138 | Val Loss: 0.7107
#
# Epoch 4/20
# Train Loss: 0.7063 | Val Loss: 0.7014
#
# Epoch 5/20
# Train Loss: 0.6934 | Val Loss: 0.6834
#
# Epoch 6/20
# Train Loss: 0.6533 | Val Loss: 0.5835
#
# Epoch 7/20
# Train Loss: 0.2955 | Val Loss: 0.1573
#
# Epoch 8/20
# Train Loss: 0.1388 | Val Loss: 0.1196
#
# Epoch 9/20
# Train Loss: 0.1262 | Val Loss: 0.1155
#
# Epoch 10/20
# Train Loss: 0.1254 | Val Loss: 0.1125
#
# Epoch 11/20
# Train Loss: 0.1221 | Val Loss: 0.1108
#
# Epoch 12/20
# Train Loss: 0.1203 | Val Loss: 0.1108
#
# Epoch 13/20
# Train Loss: 0.1164 | Val Loss: 0.1074
#
# Epoch 14/20
# Train Loss: 0.1139 | Val Loss: 0.1044
#
# Epoch 15/20
# Train Loss: 0.1131 | Val Loss: 0.1018
#
# Epoch 16/20
# Train Loss: 0.1093 | Val Loss: 0.0992
#
# Epoch 17/20
# Train Loss: 0.1073 | Val Loss: 0.0990
#
# Epoch 18/20
# Train Loss: 0.1039 | Val Loss: 0.0943
#
# Epoch 19/20
# Train Loss: 0.1036 | Val Loss: 0.0931
#
# Epoch 20/20
# Train Loss: 0.1006 | Val Loss: 0.0905
#
# Running configuration 2/12: {'learning_rate': 1e-05, 'batch_size': 4, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.7358 | Val Loss: 0.7325
#
# Epoch 2/40
# Train Loss: 0.7290 | Val Loss: 0.7257
#
# Epoch 3/40
# Train Loss: 0.7203 | Val Loss: 0.7161
#
# Epoch 4/40
# Train Loss: 0.7069 | Val Loss: 0.7010
#
# Epoch 5/40
# Train Loss: 0.6823 | Val Loss: 0.6675
#
# Epoch 6/40
# Train Loss: 0.5663 | Val Loss: 0.2639
#
# Epoch 7/40
# Train Loss: 0.1633 | Val Loss: 0.1353
#
# Epoch 8/40
# Train Loss: 0.1318 | Val Loss: 0.1195
#
# Epoch 9/40
# Train Loss: 0.1238 | Val Loss: 0.1164
#
# Epoch 10/40
# Train Loss: 0.1204 | Val Loss: 0.1142
#
# Epoch 11/40
# Train Loss: 0.1195 | Val Loss: 0.1112
#
# Epoch 12/40
# Train Loss: 0.1169 | Val Loss: 0.1084
#
# Epoch 13/40
# Train Loss: 0.1136 | Val Loss: 0.1057
#
# Epoch 14/40
# Train Loss: 0.1106 | Val Loss: 0.1020
#
# Epoch 15/40
# Train Loss: 0.1081 | Val Loss: 0.0993
#
# Epoch 16/40
# Train Loss: 0.1062 | Val Loss: 0.0965
#
# Epoch 17/40
# Train Loss: 0.1028 | Val Loss: 0.0946
#
# Epoch 18/40
# Train Loss: 0.0992 | Val Loss: 0.0925
#
# Epoch 19/40
# Train Loss: 0.0977 | Val Loss: 0.0900
#
# Epoch 20/40
# Train Loss: 0.0954 | Val Loss: 0.0887
#
# Epoch 21/40
# Train Loss: 0.0958 | Val Loss: 0.0906
#
# Epoch 22/40
# Train Loss: 0.0956 | Val Loss: 0.0873
#
# Epoch 23/40
# Train Loss: 0.0957 | Val Loss: 0.0898
#
# Epoch 24/40
# Train Loss: 0.0946 | Val Loss: 0.0860
#
# Epoch 25/40
# Train Loss: 0.0938 | Val Loss: 0.0855
#
# Epoch 26/40
# Train Loss: 0.0939 | Val Loss: 0.0849
#
# Epoch 27/40
# Train Loss: 0.0913 | Val Loss: 0.0849
#
# Epoch 28/40
# Train Loss: 0.0911 | Val Loss: 0.0840
#
# Epoch 29/40
# Train Loss: 0.0910 | Val Loss: 0.0845
#
# Epoch 30/40
# Train Loss: 0.0902 | Val Loss: 0.0830
#
# Epoch 31/40
# Train Loss: 0.0911 | Val Loss: 0.0840
#
# Epoch 32/40
# Train Loss: 0.0896 | Val Loss: 0.0822
#
# Epoch 33/40
# Train Loss: 0.0907 | Val Loss: 0.0854
#
# Epoch 34/40
# Train Loss: 0.0908 | Val Loss: 0.0818
#
# Epoch 35/40
# Train Loss: 0.0886 | Val Loss: 0.0810
#
# Epoch 36/40
# Train Loss: 0.0890 | Val Loss: 0.0806
#
# Epoch 37/40
# Train Loss: 0.0871 | Val Loss: 0.0798
#
# Epoch 38/40
# Train Loss: 0.0880 | Val Loss: 0.0806
#
# Epoch 39/40
# Train Loss: 0.0874 | Val Loss: 0.0783
#
# Epoch 40/40
# Train Loss: 0.0855 | Val Loss: 0.0778
#
# Running configuration 3/12: {'learning_rate': 1e-05, 'batch_size': 8, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.6624 | Val Loss: 0.6613
#
# Epoch 2/20
# Train Loss: 0.6592 | Val Loss: 0.6587
#
# Epoch 3/20
# Train Loss: 0.6561 | Val Loss: 0.6559
#
# Epoch 4/20
# Train Loss: 0.6532 | Val Loss: 0.6529
#
# Epoch 5/20
# Train Loss: 0.6496 | Val Loss: 0.6494
#
# Epoch 6/20
# Train Loss: 0.6449 | Val Loss: 0.6452
#
# Epoch 7/20
# Train Loss: 0.6397 | Val Loss: 0.6397
#
# Epoch 8/20
# Train Loss: 0.6318 | Val Loss: 0.6324
#
# Epoch 9/20
# Train Loss: 0.6225 | Val Loss: 0.6221
#
# Epoch 10/20
# Train Loss: 0.6085 | Val Loss: 0.6055
#
# Epoch 11/20
# Train Loss: 0.5828 | Val Loss: 0.5697
#
# Epoch 12/20
# Train Loss: 0.5095 | Val Loss: 0.4297
#
# Epoch 13/20
# Train Loss: 0.2403 | Val Loss: 0.1280
#
# Epoch 14/20
# Train Loss: 0.1607 | Val Loss: 0.1169
#
# Epoch 15/20
# Train Loss: 0.1282 | Val Loss: 0.1407
#
# Epoch 16/20
# Train Loss: 0.1222 | Val Loss: 0.1133
#
# Epoch 17/20
# Train Loss: 0.1209 | Val Loss: 0.1125
#
# Epoch 18/20
# Train Loss: 0.1186 | Val Loss: 0.1143
#
# Epoch 19/20
# Train Loss: 0.1162 | Val Loss: 0.1101
#
# Epoch 20/20
# Train Loss: 0.1153 | Val Loss: 0.1088
#
# Running configuration 4/12: {'learning_rate': 1e-05, 'batch_size': 8, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.6401 | Val Loss: 0.6385
#
# Epoch 2/40
# Train Loss: 0.6372 | Val Loss: 0.6360
#
# Epoch 3/40
# Train Loss: 0.6343 | Val Loss: 0.6333
#
# Epoch 4/40
# Train Loss: 0.6307 | Val Loss: 0.6300
#
# Epoch 5/40
# Train Loss: 0.6271 | Val Loss: 0.6261
#
# Epoch 6/40
# Train Loss: 0.6218 | Val Loss: 0.6211
#
# Epoch 7/40
# Train Loss: 0.6149 | Val Loss: 0.6145
#
# Epoch 8/40
# Train Loss: 0.6066 | Val Loss: 0.6051
#
# Epoch 9/40
# Train Loss: 0.5950 | Val Loss: 0.5907
#
# Epoch 10/40
# Train Loss: 0.5731 | Val Loss: 0.5637
#
# Epoch 11/40
# Train Loss: 0.5213 | Val Loss: 0.4756
#
# Epoch 12/40
# Train Loss: 0.3131 | Val Loss: 0.1489
#
# Epoch 13/40
# Train Loss: 0.1741 | Val Loss: 0.1422
#
# Epoch 14/40
# Train Loss: 0.1447 | Val Loss: 0.1647
#
# Epoch 15/40
# Train Loss: 0.1436 | Val Loss: 0.1336
#
# Epoch 16/40
# Train Loss: 0.1355 | Val Loss: 0.1301
#
# Epoch 17/40
# Train Loss: 0.1314 | Val Loss: 0.1308
#
# Epoch 18/40
# Train Loss: 0.1271 | Val Loss: 0.1256
#
# Epoch 19/40
# Train Loss: 0.1276 | Val Loss: 0.1231
#
# Epoch 20/40
# Train Loss: 0.1253 | Val Loss: 0.1219
#
# Epoch 21/40
# Train Loss: 0.1222 | Val Loss: 0.1178
#
# Epoch 22/40
# Train Loss: 0.1216 | Val Loss: 0.1153
#
# Epoch 23/40
# Train Loss: 0.1191 | Val Loss: 0.1130
#
# Epoch 24/40
# Train Loss: 0.1171 | Val Loss: 0.1109
#
# Epoch 25/40
# Train Loss: 0.1135 | Val Loss: 0.1078
#
# Epoch 26/40
# Train Loss: 0.1138 | Val Loss: 0.1068
#
# Epoch 27/40
# Train Loss: 0.1095 | Val Loss: 0.1032
#
# Epoch 28/40
# Train Loss: 0.1076 | Val Loss: 0.1007
#
# Epoch 29/40
# Train Loss: 0.1069 | Val Loss: 0.0984
#
# Epoch 30/40
# Train Loss: 0.1036 | Val Loss: 0.0960
#
# Epoch 31/40
# Train Loss: 0.1012 | Val Loss: 0.0937
#
# Epoch 32/40
# Train Loss: 0.0990 | Val Loss: 0.0921
#
# Epoch 33/40
# Train Loss: 0.0984 | Val Loss: 0.0924
#
# Epoch 34/40
# Train Loss: 0.0967 | Val Loss: 0.0910
#
# Epoch 35/40
# Train Loss: 0.0961 | Val Loss: 0.0889
#
# Epoch 36/40
# Train Loss: 0.0947 | Val Loss: 0.0884
#
# Epoch 37/40
# Train Loss: 0.0939 | Val Loss: 0.0889
#
# Epoch 38/40
# Train Loss: 0.0941 | Val Loss: 0.0871
#
# Epoch 39/40
# Train Loss: 0.0941 | Val Loss: 0.0868
#
# Epoch 40/40
# Train Loss: 0.0931 | Val Loss: 0.0860
#
# Running configuration 5/12: {'learning_rate': 0.0001, 'batch_size': 4, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.6612 | Val Loss: 0.6083
#
# Epoch 2/20
# Train Loss: 0.2870 | Val Loss: 0.1140
#
# Epoch 3/20
# Train Loss: 0.1161 | Val Loss: 0.0995
#
# Epoch 4/20
# Train Loss: 0.1034 | Val Loss: 0.0916
#
# Epoch 5/20
# Train Loss: 0.0970 | Val Loss: 0.0849
#
# Epoch 6/20
# Train Loss: 0.0918 | Val Loss: 0.0791
#
# Epoch 7/20
# Train Loss: 0.0850 | Val Loss: 0.0673
#
# Epoch 8/20
# Train Loss: 0.0781 | Val Loss: 0.0636
#
# Epoch 9/20
# Train Loss: 0.0622 | Val Loss: 0.0466
#
# Epoch 10/20
# Train Loss: 0.0532 | Val Loss: 0.0395
#
# Epoch 11/20
# Train Loss: 0.0436 | Val Loss: 0.0359
#
# Epoch 12/20
# Train Loss: 0.0377 | Val Loss: 0.0311
#
# Epoch 13/20
# Train Loss: 0.0346 | Val Loss: 0.0288
#
# Epoch 14/20
# Train Loss: 0.0327 | Val Loss: 0.0277
#
# Epoch 15/20
# Train Loss: 0.0309 | Val Loss: 0.0303
#
# Epoch 16/20
# Train Loss: 0.0297 | Val Loss: 0.0257
#
# Epoch 17/20
# Train Loss: 0.0269 | Val Loss: 0.0248
#
# Epoch 18/20
# Train Loss: 0.0267 | Val Loss: 0.0233
#
# Epoch 19/20
# Train Loss: 0.0255 | Val Loss: 0.0223
#
# Epoch 20/20
# Train Loss: 0.0244 | Val Loss: 0.0219
#
# Running configuration 6/12: {'learning_rate': 0.0001, 'batch_size': 4, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.5960 | Val Loss: 0.4697
#
# Epoch 2/40
# Train Loss: 0.1849 | Val Loss: 0.1123
#
# Epoch 3/40
# Train Loss: 0.1125 | Val Loss: 0.0947
#
# Epoch 4/40
# Train Loss: 0.0967 | Val Loss: 0.0851
#
# Epoch 5/40
# Train Loss: 0.0921 | Val Loss: 0.0806
#
# Epoch 6/40
# Train Loss: 0.0839 | Val Loss: 0.0711
#
# Epoch 7/40
# Train Loss: 0.0736 | Val Loss: 0.0572
#
# Epoch 8/40
# Train Loss: 0.0601 | Val Loss: 0.0494
#
# Epoch 9/40
# Train Loss: 0.0494 | Val Loss: 0.0400
#
# Epoch 10/40
# Train Loss: 0.0413 | Val Loss: 0.0338
#
# Epoch 11/40
# Train Loss: 0.0391 | Val Loss: 0.0344
#
# Epoch 12/40
# Train Loss: 0.0362 | Val Loss: 0.0312
#
# Epoch 13/40
# Train Loss: 0.0317 | Val Loss: 0.0290
#
# Epoch 14/40
# Train Loss: 0.0295 | Val Loss: 0.0265
#
# Epoch 15/40
# Train Loss: 0.0272 | Val Loss: 0.0273
#
# Epoch 16/40
# Train Loss: 0.0262 | Val Loss: 0.0241
#
# Epoch 17/40
# Train Loss: 0.0261 | Val Loss: 0.0226
#
# Epoch 18/40
# Train Loss: 0.0249 | Val Loss: 0.0228
#
# Epoch 19/40
# Train Loss: 0.0235 | Val Loss: 0.0207
#
# Epoch 20/40
# Train Loss: 0.0223 | Val Loss: 0.0209
#
# Epoch 21/40
# Train Loss: 0.0216 | Val Loss: 0.0199
#
# Epoch 22/40
# Train Loss: 0.0215 | Val Loss: 0.0199
#
# Epoch 23/40
# Train Loss: 0.0210 | Val Loss: 0.0210
#
# Epoch 24/40
# Train Loss: 0.0203 | Val Loss: 0.0192
#
# Epoch 25/40
# Train Loss: 0.0198 | Val Loss: 0.0204
#
# Epoch 26/40
# Train Loss: 0.0193 | Val Loss: 0.0176
#
# Epoch 27/40
# Train Loss: 0.0184 | Val Loss: 0.0164
#
# Epoch 28/40
# Train Loss: 0.0177 | Val Loss: 0.0164
#
# Epoch 29/40
# Train Loss: 0.0177 | Val Loss: 0.0169
#
# Epoch 30/40
# Train Loss: 0.0186 | Val Loss: 0.0169
#
# Epoch 31/40
# Train Loss: 0.0177 | Val Loss: 0.0169
#
# Epoch 32/40
# Train Loss: 0.0178 | Val Loss: 0.0162
#
# Epoch 33/40
# Train Loss: 0.0168 | Val Loss: 0.0156
#
# Epoch 34/40
# Train Loss: 0.0158 | Val Loss: 0.0149
#
# Epoch 35/40
# Train Loss: 0.0152 | Val Loss: 0.0149
#
# Epoch 36/40
# Train Loss: 0.0155 | Val Loss: 0.0142
#
# Epoch 37/40
# Train Loss: 0.0145 | Val Loss: 0.0145
#
# Epoch 38/40
# Train Loss: 0.0146 | Val Loss: 0.0140
#
# Epoch 39/40
# Train Loss: 0.0144 | Val Loss: 0.0135
#
# Epoch 40/40
# Train Loss: 0.0139 | Val Loss: 0.0135
#
# Running configuration 7/12: {'learning_rate': 0.0001, 'batch_size': 8, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.6311 | Val Loss: 0.6135
#
# Epoch 2/20
# Train Loss: 0.5570 | Val Loss: 0.4630
#
# Epoch 3/20
# Train Loss: 0.2308 | Val Loss: 0.1471
#
# Epoch 4/20
# Train Loss: 0.1325 | Val Loss: 0.1204
#
# Epoch 5/20
# Train Loss: 0.1217 | Val Loss: 0.1258
#
# Epoch 6/20
# Train Loss: 0.1110 | Val Loss: 0.1028
#
# Epoch 7/20
# Train Loss: 0.1069 | Val Loss: 0.0991
#
# Epoch 8/20
# Train Loss: 0.1017 | Val Loss: 0.0934
#
# Epoch 9/20
# Train Loss: 0.0985 | Val Loss: 0.0888
#
# Epoch 10/20
# Train Loss: 0.0959 | Val Loss: 0.0867
#
# Epoch 11/20
# Train Loss: 0.0918 | Val Loss: 0.0835
#
# Epoch 12/20
# Train Loss: 0.0908 | Val Loss: 0.0801
#
# Epoch 13/20
# Train Loss: 0.0859 | Val Loss: 0.0751
#
# Epoch 14/20
# Train Loss: 0.0803 | Val Loss: 0.0682
#
# Epoch 15/20
# Train Loss: 0.0742 | Val Loss: 0.0644
#
# Epoch 16/20
# Train Loss: 0.0681 | Val Loss: 0.0548
#
# Epoch 17/20
# Train Loss: 0.0633 | Val Loss: 0.0506
#
# Epoch 18/20
# Train Loss: 0.0552 | Val Loss: 0.0457
#
# Epoch 19/20
# Train Loss: 0.0501 | Val Loss: 0.0435
#
# Epoch 20/20
# Train Loss: 0.0494 | Val Loss: 0.0383
#
# Running configuration 8/12: {'learning_rate': 0.0001, 'batch_size': 8, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.6536 | Val Loss: 0.6357
#
# Epoch 2/40
# Train Loss: 0.5943 | Val Loss: 0.5018
#
# Epoch 3/40
# Train Loss: 0.2689 | Val Loss: 0.1909
#
# Epoch 4/40
# Train Loss: 0.1627 | Val Loss: 0.1293
#
# Epoch 5/40
# Train Loss: 0.1321 | Val Loss: 0.1236
#
# Epoch 6/40
# Train Loss: 0.1141 | Val Loss: 0.1028
#
# Epoch 7/40
# Train Loss: 0.1068 | Val Loss: 0.0958
#
# Epoch 8/40
# Train Loss: 0.1014 | Val Loss: 0.0901
#
# Epoch 9/40
# Train Loss: 0.0980 | Val Loss: 0.0860
#
# Epoch 10/40
# Train Loss: 0.0920 | Val Loss: 0.0832
#
# Epoch 11/40
# Train Loss: 0.0909 | Val Loss: 0.0788
#
# Epoch 12/40
# Train Loss: 0.0868 | Val Loss: 0.0737
#
# Epoch 13/40
# Train Loss: 0.0805 | Val Loss: 0.0665
#
# Epoch 14/40
# Train Loss: 0.0726 | Val Loss: 0.0594
#
# Epoch 15/40
# Train Loss: 0.0642 | Val Loss: 0.0536
#
# Epoch 16/40
# Train Loss: 0.0572 | Val Loss: 0.0466
#
# Epoch 17/40
# Train Loss: 0.0517 | Val Loss: 0.0408
#
# Epoch 18/40
# Train Loss: 0.0465 | Val Loss: 0.0404
#
# Epoch 19/40
# Train Loss: 0.0456 | Val Loss: 0.0344
#
# Epoch 20/40
# Train Loss: 0.0397 | Val Loss: 0.0343
#
# Epoch 21/40
# Train Loss: 0.0374 | Val Loss: 0.0337
#
# Epoch 22/40
# Train Loss: 0.0387 | Val Loss: 0.0368
#
# Epoch 23/40
# Train Loss: 0.0362 | Val Loss: 0.0322
#
# Epoch 24/40
# Train Loss: 0.0346 | Val Loss: 0.0303
#
# Epoch 25/40
# Train Loss: 0.0329 | Val Loss: 0.0300
#
# Epoch 26/40
# Train Loss: 0.0317 | Val Loss: 0.0282
#
# Epoch 27/40
# Train Loss: 0.0300 | Val Loss: 0.0275
#
# Epoch 28/40
# Train Loss: 0.0290 | Val Loss: 0.0263
#
# Epoch 29/40
# Train Loss: 0.0292 | Val Loss: 0.0279
#
# Epoch 30/40
# Train Loss: 0.0281 | Val Loss: 0.0253
#
# Epoch 31/40
# Train Loss: 0.0271 | Val Loss: 0.0243
#
# Epoch 32/40
# Train Loss: 0.0264 | Val Loss: 0.0249
#
# Epoch 33/40
# Train Loss: 0.0258 | Val Loss: 0.0246
#
# Epoch 34/40
# Train Loss: 0.0253 | Val Loss: 0.0234
#
# Epoch 35/40
# Train Loss: 0.0246 | Val Loss: 0.0228
#
# Epoch 36/40
# Train Loss: 0.0243 | Val Loss: 0.0226
#
# Epoch 37/40
# Train Loss: 0.0242 | Val Loss: 0.0231
#
# Epoch 38/40
# Train Loss: 0.0248 | Val Loss: 0.0216
#
# Epoch 39/40
# Train Loss: 0.0235 | Val Loss: 0.0216
#
# Epoch 40/40
# Train Loss: 0.0229 | Val Loss: 0.0214
#
# Running configuration 9/12: {'learning_rate': 0.001, 'batch_size': 4, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 2.4004 | Val Loss: 0.5378
#
# Epoch 2/20
# Train Loss: 0.2127 | Val Loss: 0.1332
#
# Epoch 3/20
# Train Loss: 0.1177 | Val Loss: 0.1162
#
# Epoch 4/20
# Train Loss: 0.1030 | Val Loss: 0.0945
#
# Epoch 5/20
# Train Loss: 0.0987 | Val Loss: 0.0932
#
# Epoch 6/20
# Train Loss: 0.0903 | Val Loss: 0.0724
#
# Epoch 7/20
# Train Loss: 0.0813 | Val Loss: 0.0702
#
# Epoch 8/20
# Train Loss: 0.0672 | Val Loss: 0.0540
#
# Epoch 9/20
# Train Loss: 0.0535 | Val Loss: 0.0449
#
# Epoch 10/20
# Train Loss: 0.0434 | Val Loss: 0.0352
#
# Epoch 11/20
# Train Loss: 0.0360 | Val Loss: 0.0310
#
# Epoch 12/20
# Train Loss: 0.0311 | Val Loss: 0.0277
#
# Epoch 13/20
# Train Loss: 0.0279 | Val Loss: 0.0301
#
# Epoch 14/20
# Train Loss: 0.0275 | Val Loss: 0.0242
#
# Epoch 15/20
# Train Loss: 0.0254 | Val Loss: 0.0240
#
# Epoch 16/20
# Train Loss: 0.0256 | Val Loss: 0.0244
#
# Epoch 17/20
# Train Loss: 0.0244 | Val Loss: 0.0230
#
# Epoch 18/20
# Train Loss: 0.0230 | Val Loss: 0.0210
#
# Epoch 19/20
# Train Loss: 0.0226 | Val Loss: 0.0207
#
# Epoch 20/20
# Train Loss: 0.0220 | Val Loss: 0.0203
#
# Running configuration 10/12: {'learning_rate': 0.001, 'batch_size': 4, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.8488 | Val Loss: 0.3252
#
# Epoch 2/40
# Train Loss: 0.1377 | Val Loss: 0.0933
#
# Epoch 3/40
# Train Loss: 0.0912 | Val Loss: 0.0747
#
# Epoch 4/40
# Train Loss: 0.0750 | Val Loss: 0.0601
#
# Epoch 5/40
# Train Loss: 0.0626 | Val Loss: 0.0472
#
# Epoch 6/40
# Train Loss: 0.0508 | Val Loss: 0.0396
#
# Epoch 7/40
# Train Loss: 0.0453 | Val Loss: 0.0359
#
# Epoch 8/40
# Train Loss: 0.0457 | Val Loss: 0.0338
#
# Epoch 9/40
# Train Loss: 0.0408 | Val Loss: 0.0354
#
# Epoch 10/40
# Train Loss: 0.0326 | Val Loss: 0.0255
#
# Epoch 11/40
# Train Loss: 0.0289 | Val Loss: 0.0250
#
# Epoch 12/40
# Train Loss: 0.0270 | Val Loss: 0.0239
#
# Epoch 13/40
# Train Loss: 0.0258 | Val Loss: 0.0246
#
# Epoch 14/40
# Train Loss: 0.0246 | Val Loss: 0.0220
#
# Epoch 15/40
# Train Loss: 0.0237 | Val Loss: 0.0207
#
# Epoch 16/40
# Train Loss: 0.0234 | Val Loss: 0.0203
#
# Epoch 17/40
# Train Loss: 0.0224 | Val Loss: 0.0199
#
# Epoch 18/40
# Train Loss: 0.0207 | Val Loss: 0.0188
#
# Epoch 19/40
# Train Loss: 0.0205 | Val Loss: 0.0175
#
# Epoch 20/40
# Train Loss: 0.0185 | Val Loss: 0.0164
#
# Epoch 21/40
# Train Loss: 0.0175 | Val Loss: 0.0173
#
# Epoch 22/40
# Train Loss: 0.0176 | Val Loss: 0.0159
#
# Epoch 23/40
# Train Loss: 0.0162 | Val Loss: 0.0152
#
# Epoch 24/40
# Train Loss: 0.0162 | Val Loss: 0.0140
#
# Epoch 25/40
# Train Loss: 0.0147 | Val Loss: 0.0137
#
# Epoch 26/40
# Train Loss: 0.0151 | Val Loss: 0.0132
#
# Epoch 27/40
# Train Loss: 0.0146 | Val Loss: 0.0128
#
# Epoch 28/40
# Train Loss: 0.0133 | Val Loss: 0.0123
#
# Epoch 29/40
# Train Loss: 0.0138 | Val Loss: 0.0128
#
# Epoch 30/40
# Train Loss: 0.0129 | Val Loss: 0.0112
#
# Epoch 31/40
# Train Loss: 0.0125 | Val Loss: 0.0112
#
# Epoch 32/40
# Train Loss: 0.0124 | Val Loss: 0.0113
#
# Epoch 33/40
# Train Loss: 0.0123 | Val Loss: 0.0108
#
# Epoch 34/40
# Train Loss: 0.0118 | Val Loss: 0.0109
#
# Epoch 35/40
# Train Loss: 0.0117 | Val Loss: 0.0115
#
# Epoch 36/40
# Train Loss: 0.0116 | Val Loss: 0.0110
#
# Epoch 37/40
# Train Loss: 0.0111 | Val Loss: 0.0104
#
# Epoch 38/40
# Train Loss: 0.0151 | Val Loss: 0.0127
#
# Epoch 39/40
# Train Loss: 0.0144 | Val Loss: 0.0119
#
# Epoch 40/40
# Train Loss: 0.0128 | Val Loss: 0.0112
#
# Running configuration 11/12: {'learning_rate': 0.001, 'batch_size': 8, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.5467 | Val Loss: 0.3024
#
# Epoch 2/20
# Train Loss: 0.1578 | Val Loss: 0.1106
#
# Epoch 3/20
# Train Loss: 0.1165 | Val Loss: 0.0812
#
# Epoch 4/20
# Train Loss: 0.0889 | Val Loss: 0.0789
#
# Epoch 5/20
# Train Loss: 0.0817 | Val Loss: 0.0669
#
# Epoch 6/20
# Train Loss: 0.0737 | Val Loss: 0.0624
#
# Epoch 7/20
# Train Loss: 0.0699 | Val Loss: 0.0588
#
# Epoch 8/20
# Train Loss: 0.0665 | Val Loss: 0.0557
#
# Epoch 9/20
# Train Loss: 0.0638 | Val Loss: 0.0504
#
# Epoch 10/20
# Train Loss: 0.0544 | Val Loss: 0.0602
#
# Epoch 11/20
# Train Loss: 0.0484 | Val Loss: 0.0348
#
# Epoch 12/20
# Train Loss: 0.0466 | Val Loss: 0.0350
#
# Epoch 13/20
# Train Loss: 0.0380 | Val Loss: 0.0310
#
# Epoch 14/20
# Train Loss: 0.0352 | Val Loss: 0.0327
#
# Epoch 15/20
# Train Loss: 0.0346 | Val Loss: 0.0289
#
# Epoch 16/20
# Train Loss: 0.0317 | Val Loss: 0.0266
#
# Epoch 17/20
# Train Loss: 0.0297 | Val Loss: 0.0251
#
# Epoch 18/20
# Train Loss: 0.0279 | Val Loss: 0.0243
#
# Epoch 19/20
# Train Loss: 0.0267 | Val Loss: 0.0232
#
# Epoch 20/20
# Train Loss: 0.0263 | Val Loss: 0.0224
#
# Running configuration 12/12: {'learning_rate': 0.001, 'batch_size': 8, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 7.8935 | Val Loss: 0.5391
#
# Epoch 2/40
# Train Loss: 0.5787 | Val Loss: 0.6236
#
# Epoch 3/40
# Train Loss: 0.5710 | Val Loss: 0.4217
#
# Epoch 4/40
# Train Loss: 0.3865 | Val Loss: 0.3578
#
# Epoch 5/40
# Train Loss: 0.2088 | Val Loss: 0.1540
#
# Epoch 6/40
# Train Loss: 0.1259 | Val Loss: 0.1206
#
# Epoch 7/40
# Train Loss: 0.1080 | Val Loss: 0.0985
#
# Epoch 8/40
# Train Loss: 0.0967 | Val Loss: 0.0858
#
# Epoch 9/40
# Train Loss: 0.0896 | Val Loss: 0.0805
#
# Epoch 10/40
# Train Loss: 0.0815 | Val Loss: 0.0624
#
# Epoch 11/40
# Train Loss: 0.0642 | Val Loss: 0.0536
#
# Epoch 12/40
# Train Loss: 0.0541 | Val Loss: 0.0430
#
# Epoch 13/40
# Train Loss: 0.0433 | Val Loss: 0.0360
#
# Epoch 14/40
# Train Loss: 0.0371 | Val Loss: 0.0337
#
# Epoch 15/40
# Train Loss: 0.0329 | Val Loss: 0.0296
#
# Epoch 16/40
# Train Loss: 0.0305 | Val Loss: 0.0284
#
# Epoch 17/40
# Train Loss: 0.0290 | Val Loss: 0.0253
#
# Epoch 18/40
# Train Loss: 0.0269 | Val Loss: 0.0237
#
# Epoch 19/40
# Train Loss: 0.0250 | Val Loss: 0.0227
#
# Epoch 20/40
# Train Loss: 0.0240 | Val Loss: 0.0204
#
# Epoch 21/40
# Train Loss: 0.0229 | Val Loss: 0.0203
#
# Epoch 22/40
# Train Loss: 0.0215 | Val Loss: 0.0190
#
# Epoch 23/40
# Train Loss: 0.0209 | Val Loss: 0.0181
#
# Epoch 24/40
# Train Loss: 0.0205 | Val Loss: 0.0186
#
# Epoch 25/40
# Train Loss: 0.0195 | Val Loss: 0.0176
#
# Epoch 26/40
# Train Loss: 0.0196 | Val Loss: 0.0176
#
# Epoch 27/40
# Train Loss: 0.0185 | Val Loss: 0.0167
#
# Epoch 28/40
# Train Loss: 0.0182 | Val Loss: 0.0158
#
# Epoch 29/40
# Train Loss: 0.0174 | Val Loss: 0.0155
#
# Epoch 30/40
# Train Loss: 0.0170 | Val Loss: 0.0149
#
# Epoch 31/40
# Train Loss: 0.0167 | Val Loss: 0.0148
#
# Epoch 32/40
# Train Loss: 0.0167 | Val Loss: 0.0153
#
# Epoch 33/40
# Train Loss: 0.0170 | Val Loss: 0.0149
#
# Epoch 34/40
# Train Loss: 0.0166 | Val Loss: 0.0142
#
# Epoch 35/40
# Train Loss: 0.0160 | Val Loss: 0.0139
#
# Epoch 36/40
# Train Loss: 0.0162 | Val Loss: 0.0141
#
# Epoch 37/40
# Train Loss: 0.0154 | Val Loss: 0.0133
#
# Epoch 38/40
# Train Loss: 0.0151 | Val Loss: 0.0136
#
# Epoch 39/40
# Train Loss: 0.0151 | Val Loss: 0.0131
#
# Epoch 40/40
# Train Loss: 0.0149 | Val Loss: 0.0129

# %% [markdown]
# ### III.3. UNet++

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F_nn

class ConvBlock(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.block(x)

class UNetPlusPlus(nn.Module):
    def __init__(self, in_ch=3, out_ch=1, deep_supervision=False):
        super().__init__()
        self.deep_supervision = deep_supervision
        n1 = 64
        filters = [n1, n1*2, n1*4, n1*8, n1*16]

        # Encoder
        self.conv0_0 = ConvBlock(in_ch, filters[0])
        self.conv1_0 = ConvBlock(filters[0], filters[1])
        self.conv2_0 = ConvBlock(filters[1], filters[2])
        self.conv3_0 = ConvBlock(filters[2], filters[3])
        self.conv4_0 = ConvBlock(filters[3], filters[4])

        # Decoder (nested)
        self.conv0_1 = ConvBlock(filters[0]+filters[1], filters[0])
        self.conv1_1 = ConvBlock(filters[1]+filters[2], filters[1])
        self.conv2_1 = ConvBlock(filters[2]+filters[3], filters[2])
        self.conv3_1 = ConvBlock(filters[3]+filters[4], filters[3])

        self.conv0_2 = ConvBlock(filters[0]*2 + filters[1], filters[0])
        self.conv1_2 = ConvBlock(filters[1]*2 + filters[2], filters[1])
        self.conv2_2 = ConvBlock(filters[2]*2 + filters[3], filters[2])

        self.conv0_3 = ConvBlock(filters[0]*3 + filters[1], filters[0])
        self.conv1_3 = ConvBlock(filters[1]*3 + filters[2], filters[1])

        self.conv0_4 = ConvBlock(filters[0]*4 + filters[1], filters[0])

        # Final convolution layers
        if self.deep_supervision:
            self.final = nn.ModuleList([nn.Conv2d(filters[0], out_ch, kernel_size=1) for _ in range(4)])
        else:
            self.final = nn.Conv2d(filters[0], out_ch, kernel_size=1)

        self.pool = nn.MaxPool2d(2)
        self.up = lambda x, scale_factor=2: F_nn.interpolate(x, scale_factor=scale_factor, mode='bilinear', align_corners=True)

    def forward(self, x):
        # Encoder
        x0_0 = self.conv0_0(x)
        x1_0 = self.conv1_0(self.pool(x0_0))
        x2_0 = self.conv2_0(self.pool(x1_0))
        x3_0 = self.conv3_0(self.pool(x2_0))
        x4_0 = self.conv4_0(self.pool(x3_0))

        # Decoder
        x0_1 = self.conv0_1(torch.cat([x0_0, self.up(x1_0)], 1))
        x1_1 = self.conv1_1(torch.cat([x1_0, self.up(x2_0)], 1))
        x2_1 = self.conv2_1(torch.cat([x2_0, self.up(x3_0)], 1))
        x3_1 = self.conv3_1(torch.cat([x3_0, self.up(x4_0)], 1))

        x0_2 = self.conv0_2(torch.cat([x0_0, x0_1, self.up(x1_1)], 1))
        x1_2 = self.conv1_2(torch.cat([x1_0, x1_1, self.up(x2_1)], 1))
        x2_2 = self.conv2_2(torch.cat([x2_0, x2_1, self.up(x3_1)], 1))

        x0_3 = self.conv0_3(torch.cat([x0_0, x0_1, x0_2, self.up(x1_2)], 1))
        x1_3 = self.conv1_3(torch.cat([x1_0, x1_1, x1_2, self.up(x2_2)], 1))

        x0_4 = self.conv0_4(torch.cat([x0_0, x0_1, x0_2, x0_3, self.up(x1_3)], 1))

        if self.deep_supervision:
            outputs = [self.final[i](x) for i, x in enumerate([x0_1, x0_2, x0_3, x0_4])]
            return outputs
        else:
            return self.final(x0_4)

# %%
from torch import nn

param_grid = {
    "learning_rate": [1e-5, 1e-4, 1e-3],
    "batch_size": [2, 4],
    "num_epochs": [20, 40],
    # "num_epochs": [1],
    "loss_function": ["BCEWithLogitsLoss"]
}

loss_function_map = {
    "BCEWithLogitsLoss": nn.BCEWithLogitsLoss(),
}

results_unetpp = tune_model(
    model_class=lambda: UNetPlusPlus(in_ch=3, out_ch=1, deep_supervision=False),
    model_name="UNetpp-5",
    param_grid=param_grid,
    loss_function_map=loss_function_map,
    trainset=trainset,
    valset=valset,
    device=device
)

# %% [markdown]
# ### III.4. ResUNet

# %%
# ResUNet architecture

class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ResidualBlock, self).__init__()
        self.same_channels = (in_channels == out_channels)
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.bn1   = nn.BatchNorm2d(out_channels)
        self.relu  = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.bn2   = nn.BatchNorm2d(out_channels)
        self.res_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1) if not self.same_channels else nn.Identity()

    def forward(self, x):
        identity = x
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        identity = self.res_conv(identity)
        out += identity
        return self.relu(out)

class ResUNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=1):
        super(ResUNet, self).__init__()
        self.enc1 = ResidualBlock(in_channels, 64)
        self.enc2 = ResidualBlock(64, 128)
        self.enc3 = ResidualBlock(128, 256)
        self.enc4 = ResidualBlock(256, 512)
        self.center = ResidualBlock(512, 1024)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.up4 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.dec4 = ResidualBlock(1024, 512)
        self.up3 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.dec3 = ResidualBlock(512, 256)
        self.up2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec2 = ResidualBlock(256, 128)
        self.up1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec1 = ResidualBlock(128, 64)

        self.final = nn.Conv2d(64, out_channels, kernel_size=1)

    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        center = self.center(self.pool(e4))

        d4 = self.dec4(torch.cat([self.up4(center), e4], dim=1))
        d3 = self.dec3(torch.cat([self.up3(d4), e3], dim=1))
        d2 = self.dec2(torch.cat([self.up2(d3), e2], dim=1))
        d1 = self.dec1(torch.cat([self.up1(d2), e1], dim=1))

        return self.final(d1)

# %%
from torch import nn

param_grid = {
    "learning_rate": [1e-5, 1e-4, 1e-3],
    "batch_size": [4, 8],
    "num_epochs": [20, 40],
    "loss_function": ["BCEWithLogitsLoss"]
}

loss_function_map = {
    "BCEWithLogitsLoss": nn.BCEWithLogitsLoss(),
}

results_tinyunet = tune_model(
    model_class=lambda: ResUNet(in_channels=3, out_channels=1),
    model_name="ResUNet-5",
    param_grid=param_grid,
    loss_function_map=loss_function_map,
    trainset=trainset,
    valset=valset,
    device=device
)
# Out:
# Running configuration 1/12: {'learning_rate': 1e-05, 'batch_size': 4, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.6887 | Val Loss: 0.6705
#
# Epoch 2/20
# Train Loss: 0.6390 | Val Loss: 0.6137
#
# Epoch 3/20
# Train Loss: 0.5950 | Val Loss: 0.5653
#
# Epoch 4/20
# Train Loss: 0.5538 | Val Loss: 0.5408
#
# Epoch 5/20
# Train Loss: 0.5209 | Val Loss: 0.5049
#
# Epoch 6/20
# Train Loss: 0.4861 | Val Loss: 0.4771
#
# Epoch 7/20
# Train Loss: 0.4559 | Val Loss: 0.4444
#
# Epoch 8/20
# Train Loss: 0.4311 | Val Loss: 0.4205
#
# Epoch 9/20
# Train Loss: 0.3990 | Val Loss: 0.4013
#
# Epoch 10/20
# Train Loss: 0.3805 | Val Loss: 0.3740
#
# Epoch 11/20
# Train Loss: 0.3559 | Val Loss: 0.3444
#
# Epoch 12/20
# Train Loss: 0.3304 | Val Loss: 0.3221
#
# Epoch 13/20
# Train Loss: 0.2960 | Val Loss: 0.2910
#
# Epoch 14/20
# Train Loss: 0.2468 | Val Loss: 0.2456
#
# Epoch 15/20
# Train Loss: 0.1547 | Val Loss: 0.1354
#
# Epoch 16/20
# Train Loss: 0.0665 | Val Loss: 0.0491
#
# Epoch 17/20
# Train Loss: 0.0367 | Val Loss: 0.0350
#
# Epoch 18/20
# Train Loss: 0.0300 | Val Loss: 0.0290
#
# Epoch 19/20
# Train Loss: 0.0272 | Val Loss: 0.0261
#
# Epoch 20/20
# Train Loss: 0.0261 | Val Loss: 0.0309
#
# Running configuration 2/12: {'learning_rate': 1e-05, 'batch_size': 4, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.6185 | Val Loss: 0.6322
#
# Epoch 2/40
# Train Loss: 0.5761 | Val Loss: 0.5576
#
# Epoch 3/40
# Train Loss: 0.5401 | Val Loss: 0.5060
#
# Epoch 4/40
# Train Loss: 0.5108 | Val Loss: 0.4867
#
# Epoch 5/40
# Train Loss: 0.4811 | Val Loss: 0.4664
#
# Epoch 6/40
# Train Loss: 0.4546 | Val Loss: 0.4449
#
# Epoch 7/40
# Train Loss: 0.4285 | Val Loss: 0.4204
#
# Epoch 8/40
# Train Loss: 0.4057 | Val Loss: 0.4006
#
# Epoch 9/40
# Train Loss: 0.3818 | Val Loss: 0.3725
#
# Epoch 10/40
# Train Loss: 0.3595 | Val Loss: 0.3517
#
# Epoch 11/40
# Train Loss: 0.3403 | Val Loss: 0.3345
#
# Epoch 12/40
# Train Loss: 0.3201 | Val Loss: 0.3112
#
# Epoch 13/40
# Train Loss: 0.2963 | Val Loss: 0.2912
#
# Epoch 14/40
# Train Loss: 0.2657 | Val Loss: 0.2601
#
# Epoch 15/40
# Train Loss: 0.2125 | Val Loss: 0.2151
#
# Epoch 16/40
# Train Loss: 0.1168 | Val Loss: 0.1432
#
# Epoch 17/40
# Train Loss: 0.0489 | Val Loss: 0.0519
#
# Epoch 18/40
# Train Loss: 0.0336 | Val Loss: 0.0341
#
# Epoch 19/40
# Train Loss: 0.0289 | Val Loss: 0.0388
#
# Epoch 20/40
# Train Loss: 0.0268 | Val Loss: 0.0428
#
# Epoch 21/40
# Train Loss: 0.0249 | Val Loss: 0.0254
#
# Epoch 22/40
# Train Loss: 0.0237 | Val Loss: 0.0225
#
# Epoch 23/40
# Train Loss: 0.0230 | Val Loss: 0.0234
#
# Epoch 24/40
# Train Loss: 0.0219 | Val Loss: 0.0419
#
# Epoch 25/40
# Train Loss: 0.0217 | Val Loss: 0.0405
#
# Epoch 26/40
# Train Loss: 0.0213 | Val Loss: 0.0203
#
# Epoch 27/40
# Train Loss: 0.0205 | Val Loss: 0.0261
#
# Epoch 28/40
# Train Loss: 0.0200 | Val Loss: 0.0327
#
# Epoch 29/40
# Train Loss: 0.0195 | Val Loss: 0.0238
#
# Epoch 30/40
# Train Loss: 0.0190 | Val Loss: 0.0226
#
# Epoch 31/40
# Train Loss: 0.0188 | Val Loss: 0.0253
#
# Epoch 32/40
# Train Loss: 0.0184 | Val Loss: 0.0188
#
# Epoch 33/40
# Train Loss: 0.0183 | Val Loss: 0.0192
#
# Epoch 34/40
# Train Loss: 0.0177 | Val Loss: 0.0191
#
# Epoch 35/40
# Train Loss: 0.0176 | Val Loss: 0.0172
#
# Epoch 36/40
# Train Loss: 0.0170 | Val Loss: 0.0173
#
# Epoch 37/40
# Train Loss: 0.0171 | Val Loss: 0.0168
#
# Epoch 38/40
# Train Loss: 0.0168 | Val Loss: 0.0170
#
# Epoch 39/40
# Train Loss: 0.0165 | Val Loss: 0.0167
#
# Epoch 40/40
# Train Loss: 0.0162 | Val Loss: 0.0167
#
# Running configuration 3/12: {'learning_rate': 1e-05, 'batch_size': 8, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.7041 | Val Loss: 0.6548
#
# Epoch 2/20
# Train Loss: 0.6747 | Val Loss: 0.6475
#
# Epoch 3/20
# Train Loss: 0.6476 | Val Loss: 0.6256
#
# Epoch 4/20
# Train Loss: 0.6229 | Val Loss: 0.6011
#
# Epoch 5/20
# Train Loss: 0.5996 | Val Loss: 0.5795
#
# Epoch 6/20
# Train Loss: 0.5793 | Val Loss: 0.5680
#
# Epoch 7/20
# Train Loss: 0.5572 | Val Loss: 0.5521
#
# Epoch 8/20
# Train Loss: 0.5399 | Val Loss: 0.5358
#
# Epoch 9/20
# Train Loss: 0.5225 | Val Loss: 0.5213
#
# Epoch 10/20
# Train Loss: 0.5048 | Val Loss: 0.5008
#
# Epoch 11/20
# Train Loss: 0.4871 | Val Loss: 0.4837
#
# Epoch 12/20
# Train Loss: 0.4748 | Val Loss: 0.4672
#
# Epoch 13/20
# Train Loss: 0.4608 | Val Loss: 0.4616
#
# Epoch 14/20
# Train Loss: 0.4462 | Val Loss: 0.4412
#
# Epoch 15/20
# Train Loss: 0.4370 | Val Loss: 0.4342
#
# Epoch 16/20
# Train Loss: 0.4239 | Val Loss: 0.4165
#
# Epoch 17/20
# Train Loss: 0.4114 | Val Loss: 0.4090
#
# Epoch 18/20
# Train Loss: 0.3999 | Val Loss: 0.3996
#
# Epoch 19/20
# Train Loss: 0.3906 | Val Loss: 0.3900
#
# Epoch 20/20
# Train Loss: 0.3789 | Val Loss: 0.3838
#
# Running configuration 4/12: {'learning_rate': 1e-05, 'batch_size': 8, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.7095 | Val Loss: 0.7512
#
# Epoch 2/40
# Train Loss: 0.6716 | Val Loss: 0.7229
#
# Epoch 3/40
# Train Loss: 0.6384 | Val Loss: 0.6747
#
# Epoch 4/40
# Train Loss: 0.6126 | Val Loss: 0.6315
#
# Epoch 5/40
# Train Loss: 0.5868 | Val Loss: 0.5920
#
# Epoch 6/40
# Train Loss: 0.5654 | Val Loss: 0.5664
#
# Epoch 7/40
# Train Loss: 0.5418 | Val Loss: 0.5438
#
# Epoch 8/40
# Train Loss: 0.5241 | Val Loss: 0.5221
#
# Epoch 9/40
# Train Loss: 0.5056 | Val Loss: 0.5024
#
# Epoch 10/40
# Train Loss: 0.4877 | Val Loss: 0.4935
#
# Epoch 11/40
# Train Loss: 0.4715 | Val Loss: 0.4717
#
# Epoch 12/40
# Train Loss: 0.4575 | Val Loss: 0.4580
#
# Epoch 13/40
# Train Loss: 0.4389 | Val Loss: 0.4429
#
# Epoch 14/40
# Train Loss: 0.4278 | Val Loss: 0.4223
#
# Epoch 15/40
# Train Loss: 0.4109 | Val Loss: 0.4131
#
# Epoch 16/40
# Train Loss: 0.3965 | Val Loss: 0.4031
#
# Epoch 17/40
# Train Loss: 0.3846 | Val Loss: 0.3782
#
# Epoch 18/40
# Train Loss: 0.3763 | Val Loss: 0.3728
#
# Epoch 19/40
# Train Loss: 0.3628 | Val Loss: 0.3557
#
# Epoch 20/40
# Train Loss: 0.3499 | Val Loss: 0.3533
#
# Epoch 21/40
# Train Loss: 0.3358 | Val Loss: 0.3305
#
# Epoch 22/40
# Train Loss: 0.3214 | Val Loss: 0.3148
#
# Epoch 23/40
# Train Loss: 0.3052 | Val Loss: 0.3064
#
# Epoch 24/40
# Train Loss: 0.2863 | Val Loss: 0.2905
#
# Epoch 25/40
# Train Loss: 0.2585 | Val Loss: 0.2770
#
# Epoch 26/40
# Train Loss: 0.2166 | Val Loss: 0.2334
#
# Epoch 27/40
# Train Loss: 0.1648 | Val Loss: 0.1877
#
# Epoch 28/40
# Train Loss: 0.1095 | Val Loss: 0.1380
#
# Epoch 29/40
# Train Loss: 0.0707 | Val Loss: 0.0710
#
# Epoch 30/40
# Train Loss: 0.0497 | Val Loss: 0.0457
#
# Epoch 31/40
# Train Loss: 0.0373 | Val Loss: 0.0342
#
# Epoch 32/40
# Train Loss: 0.0312 | Val Loss: 0.0299
#
# Epoch 33/40
# Train Loss: 0.0282 | Val Loss: 0.0329
#
# Epoch 34/40
# Train Loss: 0.0270 | Val Loss: 0.0260
#
# Epoch 35/40
# Train Loss: 0.0256 | Val Loss: 0.0250
#
# Epoch 36/40
# Train Loss: 0.0248 | Val Loss: 0.0245
#
# Epoch 37/40
# Train Loss: 0.0242 | Val Loss: 0.0235
#
# Epoch 38/40
# Train Loss: 0.0234 | Val Loss: 0.0231
#
# Epoch 39/40
# Train Loss: 0.0224 | Val Loss: 0.0216
#
# Epoch 40/40
# Train Loss: 0.0224 | Val Loss: 0.0227
#
# Running configuration 5/12: {'learning_rate': 0.0001, 'batch_size': 4, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.6267 | Val Loss: 0.5822
#
# Epoch 2/20
# Train Loss: 0.3769 | Val Loss: 0.3067
#
# Epoch 3/20
# Train Loss: 0.1401 | Val Loss: 0.0524
#
# Epoch 4/20
# Train Loss: 0.0371 | Val Loss: 0.0318
#
# Epoch 5/20
# Train Loss: 0.0269 | Val Loss: 0.0240
#
# Epoch 6/20
# Train Loss: 0.0236 | Val Loss: 0.0206
#
# Epoch 7/20
# Train Loss: 0.0210 | Val Loss: 0.0186
#
# Epoch 8/20
# Train Loss: 0.0195 | Val Loss: 0.0172
#
# Epoch 9/20
# Train Loss: 0.0183 | Val Loss: 0.0161
#
# Epoch 10/20
# Train Loss: 0.0168 | Val Loss: 0.0153
#
# Epoch 11/20
# Train Loss: 0.0149 | Val Loss: 0.0137
#
# Epoch 12/20
# Train Loss: 0.0139 | Val Loss: 0.0133
#
# Epoch 13/20
# Train Loss: 0.0135 | Val Loss: 0.0118
#
# Epoch 14/20
# Train Loss: 0.0128 | Val Loss: 0.0115
#
# Epoch 15/20
# Train Loss: 0.0123 | Val Loss: 0.0107
#
# Epoch 16/20
# Train Loss: 0.0115 | Val Loss: 0.0106
#
# Epoch 17/20
# Train Loss: 0.0121 | Val Loss: 0.0101
#
# Epoch 18/20
# Train Loss: 0.0113 | Val Loss: 0.0100
#
# Epoch 19/20
# Train Loss: 0.0110 | Val Loss: 0.0105
#
# Epoch 20/20
# Train Loss: 0.0109 | Val Loss: 0.0094
#
# Running configuration 6/12: {'learning_rate': 0.0001, 'batch_size': 4, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.6701 | Val Loss: 0.6054
#
# Epoch 2/40
# Train Loss: 0.4316 | Val Loss: 0.3626
#
# Epoch 3/40
# Train Loss: 0.1695 | Val Loss: 0.0499
#
# Epoch 4/40
# Train Loss: 0.0377 | Val Loss: 0.0288
#
# Epoch 5/40
# Train Loss: 0.0260 | Val Loss: 0.0243
#
# Epoch 6/40
# Train Loss: 0.0234 | Val Loss: 0.0204
#
# Epoch 7/40
# Train Loss: 0.0214 | Val Loss: 0.0193
#
# Epoch 8/40
# Train Loss: 0.0193 | Val Loss: 0.0174
#
# Epoch 9/40
# Train Loss: 0.0171 | Val Loss: 0.0160
#
# Epoch 10/40
# Train Loss: 0.0168 | Val Loss: 0.0154
#
# Epoch 11/40
# Train Loss: 0.0157 | Val Loss: 0.0140
#
# Epoch 12/40
# Train Loss: 0.0149 | Val Loss: 0.0129
#
# Epoch 13/40
# Train Loss: 0.0136 | Val Loss: 0.0124
#
# Epoch 14/40
# Train Loss: 0.0132 | Val Loss: 0.0127
#
# Epoch 15/40
# Train Loss: 0.0124 | Val Loss: 0.0115
#
# Epoch 16/40
# Train Loss: 0.0123 | Val Loss: 0.0112
#
# Epoch 17/40
# Train Loss: 0.0116 | Val Loss: 0.0106
#
# Epoch 18/40
# Train Loss: 0.0112 | Val Loss: 0.0100
#
# Epoch 19/40
# Train Loss: 0.0116 | Val Loss: 0.0103
#
# Epoch 20/40
# Train Loss: 0.0108 | Val Loss: 0.0097
#
# Epoch 21/40
# Train Loss: 0.0108 | Val Loss: 0.0098
#
# Epoch 22/40
# Train Loss: 0.0106 | Val Loss: 0.0095
#
# Epoch 23/40
# Train Loss: 0.0105 | Val Loss: 0.0097
#
# Epoch 24/40
# Train Loss: 0.0099 | Val Loss: 0.0093
#
# Epoch 25/40
# Train Loss: 0.0097 | Val Loss: 0.0090
#
# Epoch 26/40
# Train Loss: 0.0098 | Val Loss: 0.0093
#
# Epoch 27/40
# Train Loss: 0.0096 | Val Loss: 0.0087
#
# Epoch 28/40
# Train Loss: 0.0094 | Val Loss: 0.0089
#
# Epoch 29/40
# Train Loss: 0.0092 | Val Loss: 0.0092
#
# Epoch 30/40
# Train Loss: 0.0091 | Val Loss: 0.0086
#
# Epoch 31/40
# Train Loss: 0.0090 | Val Loss: 0.0089
#
# Epoch 32/40
# Train Loss: 0.0091 | Val Loss: 0.0088
#
# Epoch 33/40
# Train Loss: 0.0092 | Val Loss: 0.0084
#
# Epoch 34/40
# Train Loss: 0.0086 | Val Loss: 0.0082
#
# Epoch 35/40
# Train Loss: 0.0087 | Val Loss: 0.0084
#
# Epoch 36/40
# Train Loss: 0.0085 | Val Loss: 0.0080
#
# Epoch 37/40
# Train Loss: 0.0086 | Val Loss: 0.0086
#
# Epoch 38/40
# Train Loss: 0.0086 | Val Loss: 0.0079
#
# Epoch 39/40
# Train Loss: 0.0085 | Val Loss: 0.0079
#
# Epoch 40/40
# Train Loss: 0.0083 | Val Loss: 0.0081
#
# Running configuration 7/12: {'learning_rate': 0.0001, 'batch_size': 8, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.4830 | Val Loss: 0.5839
#
# Epoch 2/20
# Train Loss: 0.3704 | Val Loss: 0.4584
#
# Epoch 3/20
# Train Loss: 0.2924 | Val Loss: 0.3216
#
# Epoch 4/20
# Train Loss: 0.2216 | Val Loss: 0.2490
#
# Epoch 5/20
# Train Loss: 0.1164 | Val Loss: 0.1042
#
# Epoch 6/20
# Train Loss: 0.0334 | Val Loss: 0.0334
#
# Epoch 7/20
# Train Loss: 0.0264 | Val Loss: 0.0241
#
# Epoch 8/20
# Train Loss: 0.0236 | Val Loss: 0.0218
#
# Epoch 9/20
# Train Loss: 0.0218 | Val Loss: 0.0199
#
# Epoch 10/20
# Train Loss: 0.0203 | Val Loss: 0.0199
#
# Epoch 11/20
# Train Loss: 0.0191 | Val Loss: 0.0180
#
# Epoch 12/20
# Train Loss: 0.0182 | Val Loss: 0.0177
#
# Epoch 13/20
# Train Loss: 0.0178 | Val Loss: 0.0169
#
# Epoch 14/20
# Train Loss: 0.0168 | Val Loss: 0.0158
#
# Epoch 15/20
# Train Loss: 0.0164 | Val Loss: 0.0157
#
# Epoch 16/20
# Train Loss: 0.0156 | Val Loss: 0.0150
#
# Epoch 17/20
# Train Loss: 0.0149 | Val Loss: 0.0149
#
# Epoch 18/20
# Train Loss: 0.0143 | Val Loss: 0.0137
#
# Epoch 19/20
# Train Loss: 0.0139 | Val Loss: 0.0129
#
# Epoch 20/20
# Train Loss: 0.0139 | Val Loss: 0.0128
#
# Running configuration 8/12: {'learning_rate': 0.0001, 'batch_size': 8, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.6306 | Val Loss: 0.6317
#
# Epoch 2/40
# Train Loss: 0.4738 | Val Loss: 0.5250
#
# Epoch 3/40
# Train Loss: 0.3773 | Val Loss: 0.3761
#
# Epoch 4/40
# Train Loss: 0.2917 | Val Loss: 0.2968
#
# Epoch 5/40
# Train Loss: 0.1455 | Val Loss: 0.1867
#
# Epoch 6/40
# Train Loss: 0.0436 | Val Loss: 0.0366
#
# Epoch 7/40
# Train Loss: 0.0290 | Val Loss: 0.0249
#
# Epoch 8/40
# Train Loss: 0.0256 | Val Loss: 0.0221
#
# Epoch 9/40
# Train Loss: 0.0227 | Val Loss: 0.0204
#
# Epoch 10/40
# Train Loss: 0.0216 | Val Loss: 0.0200
#
# Epoch 11/40
# Train Loss: 0.0205 | Val Loss: 0.0186
#
# Epoch 12/40
# Train Loss: 0.0188 | Val Loss: 0.0171
#
# Epoch 13/40
# Train Loss: 0.0183 | Val Loss: 0.0166
#
# Epoch 14/40
# Train Loss: 0.0171 | Val Loss: 0.0160
#
# Epoch 15/40
# Train Loss: 0.0163 | Val Loss: 0.0158
#
# Epoch 16/40
# Train Loss: 0.0157 | Val Loss: 0.0146
#
# Epoch 17/40
# Train Loss: 0.0157 | Val Loss: 0.0142
#
# Epoch 18/40
# Train Loss: 0.0154 | Val Loss: 0.0138
#
# Epoch 19/40
# Train Loss: 0.0151 | Val Loss: 0.0133
#
# Epoch 20/40
# Train Loss: 0.0148 | Val Loss: 0.0132
#
# Epoch 21/40
# Train Loss: 0.0138 | Val Loss: 0.0128
#
# Epoch 22/40
# Train Loss: 0.0134 | Val Loss: 0.0125
#
# Epoch 23/40
# Train Loss: 0.0134 | Val Loss: 0.0121
#
# Epoch 24/40
# Train Loss: 0.0132 | Val Loss: 0.0117
#
# Epoch 25/40
# Train Loss: 0.0127 | Val Loss: 0.0114
#
# Epoch 26/40
# Train Loss: 0.0123 | Val Loss: 0.0111
#
# Epoch 27/40
# Train Loss: 0.0118 | Val Loss: 0.0110
#
# Epoch 28/40
# Train Loss: 0.0117 | Val Loss: 0.0106
#
# Epoch 29/40
# Train Loss: 0.0115 | Val Loss: 0.0104
#
# Epoch 30/40
# Train Loss: 0.0114 | Val Loss: 0.0102
#
# Epoch 31/40
# Train Loss: 0.0112 | Val Loss: 0.0105
#
# Epoch 32/40
# Train Loss: 0.0110 | Val Loss: 0.0100
#
# Epoch 33/40
# Train Loss: 0.0106 | Val Loss: 0.0097
#
# Epoch 34/40
# Train Loss: 0.0105 | Val Loss: 0.0097
#
# Epoch 35/40
# Train Loss: 0.0103 | Val Loss: 0.0094
#
# Epoch 36/40
# Train Loss: 0.0101 | Val Loss: 0.0093
#
# Epoch 37/40
# Train Loss: 0.0099 | Val Loss: 0.0091
#
# Epoch 38/40
# Train Loss: 0.0099 | Val Loss: 0.0093
#
# Epoch 39/40
# Train Loss: 0.0097 | Val Loss: 0.0094
#
# Epoch 40/40
# Train Loss: 0.0099 | Val Loss: 0.0090
#
# Running configuration 9/12: {'learning_rate': 0.001, 'batch_size': 4, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.2359 | Val Loss: 0.0639
#
# Epoch 2/20
# Train Loss: 0.0346 | Val Loss: 0.0244
#
# Epoch 3/20
# Train Loss: 0.0238 | Val Loss: 0.0206
#
# Epoch 4/20
# Train Loss: 0.0199 | Val Loss: 0.0168
#
# Epoch 5/20
# Train Loss: 0.0173 | Val Loss: 0.0141
#
# Epoch 6/20
# Train Loss: 0.0149 | Val Loss: 0.0129
#
# Epoch 7/20
# Train Loss: 0.0131 | Val Loss: 0.0114
#
# Epoch 8/20
# Train Loss: 0.0122 | Val Loss: 0.0101
#
# Epoch 9/20
# Train Loss: 0.0116 | Val Loss: 0.0098
#
# Epoch 10/20
# Train Loss: 0.0109 | Val Loss: 0.0097
#
# Epoch 11/20
# Train Loss: 0.0105 | Val Loss: 0.0091
#
# Epoch 12/20
# Train Loss: 0.0098 | Val Loss: 0.0085
#
# Epoch 13/20
# Train Loss: 0.0100 | Val Loss: 0.0092
#
# Epoch 14/20
# Train Loss: 0.0098 | Val Loss: 0.0081
#
# Epoch 15/20
# Train Loss: 0.0094 | Val Loss: 0.0081
#
# Epoch 16/20
# Train Loss: 0.0097 | Val Loss: 0.0080
#
# Epoch 17/20
# Train Loss: 0.0093 | Val Loss: 0.0077
#
# Epoch 18/20
# Train Loss: 0.0092 | Val Loss: 0.0077
#
# Epoch 19/20
# Train Loss: 0.0085 | Val Loss: 0.0078
#
# Epoch 20/20
# Train Loss: 0.0086 | Val Loss: 0.0073
#
# Running configuration 10/12: {'learning_rate': 0.001, 'batch_size': 4, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.2349 | Val Loss: 0.0505
#
# Epoch 2/40
# Train Loss: 0.0308 | Val Loss: 0.0251
#
# Epoch 3/40
# Train Loss: 0.0233 | Val Loss: 0.0192
#
# Epoch 4/40
# Train Loss: 0.0200 | Val Loss: 0.0182
#
# Epoch 5/40
# Train Loss: 0.0176 | Val Loss: 0.0143
#
# Epoch 6/40
# Train Loss: 0.0160 | Val Loss: 0.0130
#
# Epoch 7/40
# Train Loss: 0.0138 | Val Loss: 0.0118
#
# Epoch 8/40
# Train Loss: 0.0124 | Val Loss: 0.0110
#
# Epoch 9/40
# Train Loss: 0.0121 | Val Loss: 0.0105
#
# Epoch 10/40
# Train Loss: 0.0106 | Val Loss: 0.0091
#
# Epoch 11/40
# Train Loss: 0.0106 | Val Loss: 0.0086
#
# Epoch 12/40
# Train Loss: 0.0096 | Val Loss: 0.0084
#
# Epoch 13/40
# Train Loss: 0.0095 | Val Loss: 0.0081
#
# Epoch 14/40
# Train Loss: 0.0092 | Val Loss: 0.0086
#
# Epoch 15/40
# Train Loss: 0.0087 | Val Loss: 0.0077
#
# Epoch 16/40
# Train Loss: 0.0086 | Val Loss: 0.0077
#
# Epoch 17/40
# Train Loss: 0.0082 | Val Loss: 0.0076
#
# Epoch 18/40
# Train Loss: 0.0083 | Val Loss: 0.0075
#
# Epoch 19/40
# Train Loss: 0.0082 | Val Loss: 0.0074
#
# Epoch 20/40
# Train Loss: 0.0082 | Val Loss: 0.0073
#
# Epoch 21/40
# Train Loss: 0.0081 | Val Loss: 0.0071
#
# Epoch 22/40
# Train Loss: 0.0084 | Val Loss: 0.0076
#
# Epoch 23/40
# Train Loss: 0.0076 | Val Loss: 0.0072
#
# Epoch 24/40
# Train Loss: 0.0076 | Val Loss: 0.0072
#
# Epoch 25/40
# Train Loss: 0.0075 | Val Loss: 0.0068
#
# Epoch 26/40
# Train Loss: 0.0074 | Val Loss: 0.0072
#
# Epoch 27/40
# Train Loss: 0.0074 | Val Loss: 0.0072
#
# Epoch 28/40
# Train Loss: 0.0071 | Val Loss: 0.0068
#
# Epoch 29/40
# Train Loss: 0.0071 | Val Loss: 0.0065
#
# Epoch 30/40
# Train Loss: 0.0070 | Val Loss: 0.0066
#
# Epoch 31/40
# Train Loss: 0.0069 | Val Loss: 0.0064
#
# Epoch 32/40
# Train Loss: 0.0071 | Val Loss: 0.0065
#
# Epoch 33/40
# Train Loss: 0.0072 | Val Loss: 0.0068
#
# Epoch 34/40
# Train Loss: 0.0071 | Val Loss: 0.0067
#
# Epoch 35/40
# Train Loss: 0.0069 | Val Loss: 0.0069
#
# Epoch 36/40
# Train Loss: 0.0070 | Val Loss: 0.0064
#
# Epoch 37/40
# Train Loss: 0.0072 | Val Loss: 0.0084
#
# Epoch 38/40
# Train Loss: 0.0070 | Val Loss: 0.0071
#
# Epoch 39/40
# Train Loss: 0.0067 | Val Loss: 0.0061
#
# Epoch 40/40
# Train Loss: 0.0066 | Val Loss: 0.0066
#
# Running configuration 11/12: {'learning_rate': 0.001, 'batch_size': 8, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.3330 | Val Loss: 0.1040
#
# Epoch 2/20
# Train Loss: 0.0480 | Val Loss: 0.1706
#
# Epoch 3/20
# Train Loss: 0.0290 | Val Loss: 0.0387
#
# Epoch 4/20
# Train Loss: 0.0243 | Val Loss: 0.0408
#
# Epoch 5/20
# Train Loss: 0.0211 | Val Loss: 0.0219
#
# Epoch 6/20
# Train Loss: 0.0186 | Val Loss: 0.0159
#
# Epoch 7/20
# Train Loss: 0.0167 | Val Loss: 0.0145
#
# Epoch 8/20
# Train Loss: 0.0155 | Val Loss: 0.0146
#
# Epoch 9/20
# Train Loss: 0.0143 | Val Loss: 0.0131
#
# Epoch 10/20
# Train Loss: 0.0131 | Val Loss: 0.0117
#
# Epoch 11/20
# Train Loss: 0.0129 | Val Loss: 0.0112
#
# Epoch 12/20
# Train Loss: 0.0120 | Val Loss: 0.0101
#
# Epoch 13/20
# Train Loss: 0.0110 | Val Loss: 0.0100
#
# Epoch 14/20
# Train Loss: 0.0106 | Val Loss: 0.0091
#
# Epoch 15/20
# Train Loss: 0.0100 | Val Loss: 0.0088
#
# Epoch 16/20
# Train Loss: 0.0098 | Val Loss: 0.0087
#
# Epoch 17/20
# Train Loss: 0.0096 | Val Loss: 0.0084
#
# Epoch 18/20
# Train Loss: 0.0090 | Val Loss: 0.0079
#
# Epoch 19/20
# Train Loss: 0.0089 | Val Loss: 0.0084
#
# Epoch 20/20
# Train Loss: 0.0090 | Val Loss: 0.0078
#
# Running configuration 12/12: {'learning_rate': 0.001, 'batch_size': 8, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.3378 | Val Loss: 0.1316
#
# Epoch 2/40
# Train Loss: 0.0578 | Val Loss: 0.0819
#
# Epoch 3/40
# Train Loss: 0.0300 | Val Loss: 0.0347
#
# Epoch 4/40
# Train Loss: 0.0243 | Val Loss: 0.0280
#
# Epoch 5/40
# Train Loss: 0.0227 | Val Loss: 0.0224
#
# Epoch 6/40
# Train Loss: 0.0205 | Val Loss: 0.0188
#
# Epoch 7/40
# Train Loss: 0.0182 | Val Loss: 0.0181
#
# Epoch 8/40
# Train Loss: 0.0168 | Val Loss: 0.0142
#
# Epoch 9/40
# Train Loss: 0.0149 | Val Loss: 0.0138
#
# Epoch 10/40
# Train Loss: 0.0148 | Val Loss: 0.0147
#
# Epoch 11/40
# Train Loss: 0.0137 | Val Loss: 0.0125
#
# Epoch 12/40
# Train Loss: 0.0122 | Val Loss: 0.0113
#
# Epoch 13/40
# Train Loss: 0.0118 | Val Loss: 0.0103
#
# Epoch 14/40
# Train Loss: 0.0110 | Val Loss: 0.0100
#
# Epoch 15/40
# Train Loss: 0.0107 | Val Loss: 0.0096
#
# Epoch 16/40
# Train Loss: 0.0106 | Val Loss: 0.0093
#
# Epoch 17/40
# Train Loss: 0.0098 | Val Loss: 0.0089
#
# Epoch 18/40
# Train Loss: 0.0097 | Val Loss: 0.0085
#
# Epoch 19/40
# Train Loss: 0.0091 | Val Loss: 0.0084
#
# Epoch 20/40
# Train Loss: 0.0093 | Val Loss: 0.0083
#
# Epoch 21/40
# Train Loss: 0.0088 | Val Loss: 0.0081
#
# Epoch 22/40
# Train Loss: 0.0090 | Val Loss: 0.0080
#
# Epoch 23/40
# Train Loss: 0.0090 | Val Loss: 0.0076
#
# Epoch 24/40
# Train Loss: 0.0088 | Val Loss: 0.0086
#
# Epoch 25/40
# Train Loss: 0.0085 | Val Loss: 0.0079
#
# Epoch 26/40
# Train Loss: 0.0082 | Val Loss: 0.0073
#
# Epoch 27/40
# Train Loss: 0.0079 | Val Loss: 0.0075
#
# Epoch 28/40
# Train Loss: 0.0079 | Val Loss: 0.0073
#
# Epoch 29/40
# Train Loss: 0.0080 | Val Loss: 0.0083
#
# Epoch 30/40
# Train Loss: 0.0077 | Val Loss: 0.0080
#
# Epoch 31/40
# Train Loss: 0.0082 | Val Loss: 0.0071
#
# Epoch 32/40
# Train Loss: 0.0079 | Val Loss: 0.0074
#
# Epoch 33/40
# Train Loss: 0.0077 | Val Loss: 0.0071
#
# Epoch 34/40
# Train Loss: 0.0076 | Val Loss: 0.0070
#
# Epoch 35/40
# Train Loss: 0.0079 | Val Loss: 0.0070
#
# Epoch 36/40
# Train Loss: 0.0075 | Val Loss: 0.0067
#
# Epoch 37/40
# Train Loss: 0.0073 | Val Loss: 0.0067
#
# Epoch 38/40
# Train Loss: 0.0074 | Val Loss: 0.0065
#
# Epoch 39/40
# Train Loss: 0.0072 | Val Loss: 0.0064
#
# Epoch 40/40
# Train Loss: 0.0071 | Val Loss: 0.0065

# %% [markdown]
# ### III.5. ResUNet Depper (Custom architecture)

# %%
import numpy as np
import random # Used for transforms (to allow transform on both images and mask)
import matplotlib.pyplot as plt
import gc
# ResUNet architecture

class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ResidualBlock, self).__init__()
        self.same_channels = (in_channels == out_channels)
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.bn1   = nn.BatchNorm2d(out_channels)
        self.relu  = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.bn2   = nn.BatchNorm2d(out_channels)
        self.res_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1) if not self.same_channels else nn.Identity()

    def forward(self, x):
        identity = x
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        identity = self.res_conv(identity)
        out += identity
        return self.relu(out)

class ResUNet_deeper(nn.Module):
    def __init__(self, in_channels=3, out_channels=1):
        super(ResUNet_deeper, self).__init__()
        self.enc1 = ResidualBlock(in_channels, 64)
        self.enc2 = ResidualBlock(64, 128)
        self.enc3 = ResidualBlock(128, 256)
        self.enc4 = ResidualBlock(256, 512)
        self.enc5 = ResidualBlock(512, 1024)

        self.center = ResidualBlock(1024, 2048)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.up5 = nn.ConvTranspose2d(2048, 1024, kernel_size=2, stride=2)
        self.dec5 = ResidualBlock(2048, 1024)

        self.up4 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.dec4 = ResidualBlock(1024, 512)

        self.up3 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.dec3 = ResidualBlock(512, 256)

        self.up2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec2 = ResidualBlock(256, 128)

        self.up1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec1 = ResidualBlock(128, 64)

        self.final = nn.Conv2d(64, out_channels, kernel_size=1)

    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        e5 = self.enc5(self.pool(e4))

        center = self.center(self.pool(e5))

        d5 = self.dec5(torch.cat([self.up5(center), e5], dim=1))
        d4 = self.dec4(torch.cat([self.up4(d5), e4], dim=1))
        d3 = self.dec3(torch.cat([self.up3(d4), e3], dim=1))
        d2 = self.dec2(torch.cat([self.up2(d3), e2], dim=1))
        d1 = self.dec1(torch.cat([self.up1(d2), e1], dim=1))

        return self.final(d1)

# %%
from torch import nn

param_grid = {
    "learning_rate": [1e-5, 1e-4, 1e-3],
    "batch_size": [2, 4],
    "num_epochs": [20, 40],
    "loss_function": ["BCEWithLogitsLoss"]
}

loss_function_map = {
    "BCEWithLogitsLoss": nn.BCEWithLogitsLoss(),
}

results_tinyunet = tune_model(
    model_class=lambda: ResUNet_deeper(in_channels=3, out_channels=1),
    model_name="ResUNet_deeper-5",
    param_grid=param_grid,
    loss_function_map=loss_function_map,
    trainset=trainset,
    valset=valset,
    device=device
)

# %% [markdown]
# ### III.6. ResUNet++ (Custom architecture)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F_nn

class ConvBlock(nn.Module): # do not modify shape asides number of channels
    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()
        self.same_channels = (in_channels == out_channels)
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.bn1   = nn.BatchNorm2d(out_channels)
        self.relu  = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.bn2   = nn.BatchNorm2d(out_channels)
        self.res_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1) if not self.same_channels else nn.Identity()

    def forward(self, x):
        identity = x
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        identity = self.res_conv(identity)
        out += identity
        return self.relu(out)

class ResUNetPlusPlus(nn.Module):
    def __init__(self, in_ch=3, out_ch=1, deep_supervision=False):
        super().__init__()
        self.deep_supervision = deep_supervision
        n1 = 64
        filters = [n1, n1*2, n1*4, n1*8, n1*16]

        # Encoder
        self.conv0_0 = ConvBlock(in_ch, filters[0]) 
        self.conv1_0 = ConvBlock(filters[0], filters[1])
        self.conv2_0 = ConvBlock(filters[1], filters[2])
        self.conv3_0 = ConvBlock(filters[2], filters[3])
        self.conv4_0 = ConvBlock(filters[3], filters[4])

        # Decoder (nested)
        self.conv0_1 = ConvBlock(filters[0]+filters[1], filters[0]) # 64+128 -> 64
        self.conv1_1 = ConvBlock(filters[1]+filters[2], filters[1]) # 128+256 -> 128
        self.conv2_1 = ConvBlock(filters[2]+filters[3], filters[2]) # 256+512 -> 256
        self.conv3_1 = ConvBlock(filters[3]+filters[4], filters[3]) # 512+1024 -> 512

        self.conv0_2 = ConvBlock(filters[0]*2 + filters[1], filters[0]) # 64*2+128=256 -> 64
        self.conv1_2 = ConvBlock(filters[1]*2 + filters[2], filters[1]) # 512 -> 128
        self.conv2_2 = ConvBlock(filters[2]*2 + filters[3], filters[2]) # 1024 -> 256

        self.conv0_3 = ConvBlock(filters[0]*3 + filters[1], filters[0]) # 64*3+128 ->64
        self.conv1_3 = ConvBlock(filters[1]*3 + filters[2], filters[1]) # 128*3+256 -> 128

        self.conv0_4 = ConvBlock(filters[0]*4 + filters[1], filters[0]) # 64*4+128 -> 64

        # Final convolution layers
        if self.deep_supervision:
            self.final = nn.ModuleList([nn.Conv2d(filters[0], out_ch, kernel_size=1) for _ in range(4)])
        else:
            self.final = nn.Conv2d(filters[0], out_ch, kernel_size=1)

        self.pool = nn.MaxPool2d(2)
        self.up = lambda x, scale_factor=2: F_nn.interpolate(x, scale_factor=scale_factor, mode='bilinear', align_corners=True)

    def forward(self, x):
        # Encoder
        x0_0 = self.conv0_0(x) # c = 64, h = 256
        x1_0 = self.conv1_0(self.pool(x0_0)) # c=128, h=128
        x2_0 = self.conv2_0(self.pool(x1_0)) # c=256, h=64
        x3_0 = self.conv3_0(self.pool(x2_0)) # c=512, h=32
        x4_0 = self.conv4_0(self.pool(x3_0)) # c=1024, h=16

        # Decoder
        x0_1 = self.conv0_1(torch.cat([x0_0, self.up(x1_0)], 1))
        # x0_1 c=64 h=
        # x0_0 c=64, h=256, upx1_0 c=128, h=128 -> concat c=64+128, h=128
        x1_1 = self.conv1_1(torch.cat([x1_0, self.up(x2_0)], 1))
        x2_1 = self.conv2_1(torch.cat([x2_0, self.up(x3_0)], 1))
        x3_1 = self.conv3_1(torch.cat([x3_0, self.up(x4_0)], 1))

        x0_2 = self.conv0_2(torch.cat([x0_0, x0_1, self.up(x1_1)], 1))
        x1_2 = self.conv1_2(torch.cat([x1_0, x1_1, self.up(x2_1)], 1))
        x2_2 = self.conv2_2(torch.cat([x2_0, x2_1, self.up(x3_1)], 1))

        x0_3 = self.conv0_3(torch.cat([x0_0, x0_1, x0_2, self.up(x1_2)], 1))
        x1_3 = self.conv1_3(torch.cat([x1_0, x1_1, x1_2, self.up(x2_2)], 1))

        x0_4 = self.conv0_4(torch.cat([x0_0, x0_1, x0_2, x0_3, self.up(x1_3)], 1))

        if self.deep_supervision:
            outputs = [self.final[i](x) for i, x in enumerate([x0_1, x0_2, x0_3, x0_4])]
            return outputs
        else:
            return self.final(x0_4)

# %%
from torch import nn

param_grid = {
    "learning_rate": [1e-5, 1e-4, 1e-3],
    "batch_size": [2, 4],
    "num_epochs": [20, 40],
    "loss_function": ["BCEWithLogitsLoss"]
}

loss_function_map = {
    "BCEWithLogitsLoss": nn.BCEWithLogitsLoss(),
}

results_tinyunet = tune_model(
    model_class=lambda: ResUNetPlusPlus(in_ch=3, out_ch=1, deep_supervision=False),
    model_name="ResUNet_deeper-5",
    param_grid=param_grid,
    loss_function_map=loss_function_map,
    trainset=trainset,
    valset=valset,
    device=device
)
# Out:
# Running configuration 1/12: {'learning_rate': 1e-05, 'batch_size': 2, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.4406 | Val Loss: 0.3567
#
# Epoch 2/20
# Train Loss: 0.2302 | Val Loss: 0.1959
#
# Epoch 3/20
# Train Loss: 0.1451 | Val Loss: 0.1276
#
# Epoch 4/20
# Train Loss: 0.1022 | Val Loss: 0.0872
#
# Epoch 5/20
# Train Loss: 0.0751 | Val Loss: 0.0640
#
# Epoch 6/20
# Train Loss: 0.0547 | Val Loss: 0.0454
#
# Epoch 7/20
# Train Loss: 0.0409 | Val Loss: 0.0354
#
# Epoch 8/20
# Train Loss: 0.0316 | Val Loss: 0.0272
#
# Epoch 9/20
# Train Loss: 0.0253 | Val Loss: 0.0219
#
# Epoch 10/20
# Train Loss: 0.0221 | Val Loss: 0.0197
#
# Epoch 11/20
# Train Loss: 0.0191 | Val Loss: 0.0174
#
# Epoch 12/20
# Train Loss: 0.0175 | Val Loss: 0.0157
#
# Epoch 13/20
# Train Loss: 0.0158 | Val Loss: 0.0147
#
# Epoch 14/20
# Train Loss: 0.0147 | Val Loss: 0.0144
#
# Epoch 15/20
# Train Loss: 0.0140 | Val Loss: 0.0134
#
# Epoch 16/20
# Train Loss: 0.0135 | Val Loss: 0.0127
#
# Epoch 17/20
# Train Loss: 0.0131 | Val Loss: 0.0128
#
# Epoch 18/20
# Train Loss: 0.0123 | Val Loss: 0.0122
#
# Epoch 19/20
# Train Loss: 0.0120 | Val Loss: 0.0114
#
# Epoch 20/20
# Train Loss: 0.0120 | Val Loss: 0.0127
#
# Running configuration 2/12: {'learning_rate': 1e-05, 'batch_size': 2, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.3270 | Val Loss: 0.2685
#
# Epoch 2/40
# Train Loss: 0.1616 | Val Loss: 0.1295
#
# Epoch 3/40
# Train Loss: 0.1044 | Val Loss: 0.0909
#
# Epoch 4/40
# Train Loss: 0.0763 | Val Loss: 0.0642
#
# Epoch 5/40
# Train Loss: 0.0597 | Val Loss: 0.0540
#
# Epoch 6/40
# Train Loss: 0.0486 | Val Loss: 0.0434
#
# Epoch 7/40
# Train Loss: 0.0403 | Val Loss: 0.0354
#
# Epoch 8/40
# Train Loss: 0.0337 | Val Loss: 0.0296
#
# Epoch 9/40
# Train Loss: 0.0293 | Val Loss: 0.0265
#
# Epoch 10/40
# Train Loss: 0.0254 | Val Loss: 0.0228
#
# Epoch 11/40
# Train Loss: 0.0225 | Val Loss: 0.0204
#
# Epoch 12/40
# Train Loss: 0.0197 | Val Loss: 0.0180
#
# Epoch 13/40
# Train Loss: 0.0179 | Val Loss: 0.0174
#
# Epoch 14/40
# Train Loss: 0.0164 | Val Loss: 0.0159
#
# Epoch 15/40
# Train Loss: 0.0151 | Val Loss: 0.0140
#
# Epoch 16/40
# Train Loss: 0.0146 | Val Loss: 0.0135
#
# Epoch 17/40
# Train Loss: 0.0136 | Val Loss: 0.0128
#
# Epoch 18/40
# Train Loss: 0.0127 | Val Loss: 0.0127
#
# Epoch 19/40
# Train Loss: 0.0127 | Val Loss: 0.0121
#
# Epoch 20/40
# Train Loss: 0.0120 | Val Loss: 0.0121
#
# Epoch 21/40
# Train Loss: 0.0116 | Val Loss: 0.0112
#
# Epoch 22/40
# Train Loss: 0.0111 | Val Loss: 0.0110
#
# Epoch 23/40
# Train Loss: 0.0113 | Val Loss: 0.0110
#
# Epoch 24/40
# Train Loss: 0.0107 | Val Loss: 0.0106
#
# Epoch 25/40
# Train Loss: 0.0107 | Val Loss: 0.0107
#
# Epoch 26/40
# Train Loss: 0.0105 | Val Loss: 0.0102
#
# Epoch 27/40
# Train Loss: 0.0101 | Val Loss: 0.0104
#
# Epoch 28/40
# Train Loss: 0.0101 | Val Loss: 0.0101
#
# Epoch 29/40
# Train Loss: 0.0097 | Val Loss: 0.0101
#
# Epoch 30/40
# Train Loss: 0.0098 | Val Loss: 0.0099
#
# Epoch 31/40
# Train Loss: 0.0093 | Val Loss: 0.0096
#
# Epoch 32/40
# Train Loss: 0.0093 | Val Loss: 0.0095
#
# Epoch 33/40
# Train Loss: 0.0093 | Val Loss: 0.0095
#
# Epoch 34/40
# Train Loss: 0.0090 | Val Loss: 0.0093
#
# Epoch 35/40
# Train Loss: 0.0091 | Val Loss: 0.0093
#
# Epoch 36/40
# Train Loss: 0.0089 | Val Loss: 0.0098
#
# Epoch 37/40
# Train Loss: 0.0088 | Val Loss: 0.0094
#
# Epoch 38/40
# Train Loss: 0.0089 | Val Loss: 0.0092
#
# Epoch 39/40
# Train Loss: 0.0089 | Val Loss: 0.0091
#
# Epoch 40/40
# Train Loss: 0.0088 | Val Loss: 0.0096
#
# Running configuration 3/12: {'learning_rate': 1e-05, 'batch_size': 4, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.7060 | Val Loss: 0.6701
#
# Epoch 2/20
# Train Loss: 0.4851 | Val Loss: 0.4750
#
# Epoch 3/20
# Train Loss: 0.3708 | Val Loss: 0.3485
#
# Epoch 4/20
# Train Loss: 0.2976 | Val Loss: 0.2788
#
# Epoch 5/20
# Train Loss: 0.2454 | Val Loss: 0.2295
#
# Epoch 6/20
# Train Loss: 0.2061 | Val Loss: 0.1983
#
# Epoch 7/20
# Train Loss: 0.1721 | Val Loss: 0.1642
#
# Epoch 8/20
# Train Loss: 0.1480 | Val Loss: 0.1419
#
# Epoch 9/20
# Train Loss: 0.1244 | Val Loss: 0.1171
#
# Epoch 10/20
# Train Loss: 0.1047 | Val Loss: 0.0980
#
# Epoch 11/20
# Train Loss: 0.0891 | Val Loss: 0.0848
#
# Epoch 12/20
# Train Loss: 0.0746 | Val Loss: 0.0680
#
# Epoch 13/20
# Train Loss: 0.0619 | Val Loss: 0.0592
#
# Epoch 14/20
# Train Loss: 0.0509 | Val Loss: 0.0468
#
# Epoch 15/20
# Train Loss: 0.0423 | Val Loss: 0.0395
#
# Epoch 16/20
# Train Loss: 0.0362 | Val Loss: 0.0320
#
# Epoch 17/20
# Train Loss: 0.0310 | Val Loss: 0.0272
#
# Epoch 18/20
# Train Loss: 0.0275 | Val Loss: 0.0250
#
# Epoch 19/20
# Train Loss: 0.0251 | Val Loss: 0.0231
#
# Epoch 20/20
# Train Loss: 0.0232 | Val Loss: 0.0209
#
# Running configuration 4/12: {'learning_rate': 1e-05, 'batch_size': 4, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.5600 | Val Loss: 0.5887
#
# Epoch 2/40
# Train Loss: 0.3723 | Val Loss: 0.3847
#
# Epoch 3/40
# Train Loss: 0.2708 | Val Loss: 0.2530
#
# Epoch 4/40
# Train Loss: 0.2079 | Val Loss: 0.1926
#
# Epoch 5/40
# Train Loss: 0.1663 | Val Loss: 0.1570
#
# Epoch 6/40
# Train Loss: 0.1353 | Val Loss: 0.1244
#
# Epoch 7/40
# Train Loss: 0.1139 | Val Loss: 0.1107
#
# Epoch 8/40
# Train Loss: 0.0950 | Val Loss: 0.0890
#
# Epoch 9/40
# Train Loss: 0.0831 | Val Loss: 0.0779
#
# Epoch 10/40
# Train Loss: 0.0708 | Val Loss: 0.0653
#
# Epoch 11/40
# Train Loss: 0.0630 | Val Loss: 0.0583
#
# Epoch 12/40
# Train Loss: 0.0550 | Val Loss: 0.0503
#
# Epoch 13/40
# Train Loss: 0.0495 | Val Loss: 0.0448
#
# Epoch 14/40
# Train Loss: 0.0438 | Val Loss: 0.0408
#
# Epoch 15/40
# Train Loss: 0.0392 | Val Loss: 0.0364
#
# Epoch 16/40
# Train Loss: 0.0354 | Val Loss: 0.0339
#
# Epoch 17/40
# Train Loss: 0.0322 | Val Loss: 0.0296
#
# Epoch 18/40
# Train Loss: 0.0293 | Val Loss: 0.0271
#
# Epoch 19/40
# Train Loss: 0.0279 | Val Loss: 0.0248
#
# Epoch 20/40
# Train Loss: 0.0258 | Val Loss: 0.0229
#
# Epoch 21/40
# Train Loss: 0.0238 | Val Loss: 0.0232
#
# Epoch 22/40
# Train Loss: 0.0224 | Val Loss: 0.0211
#
# Epoch 23/40
# Train Loss: 0.0211 | Val Loss: 0.0206
#
# Epoch 24/40
# Train Loss: 0.0197 | Val Loss: 0.0190
#
# Epoch 25/40
# Train Loss: 0.0187 | Val Loss: 0.0171
#
# Epoch 26/40
# Train Loss: 0.0181 | Val Loss: 0.0161
#
# Epoch 27/40
# Train Loss: 0.0169 | Val Loss: 0.0159
#
# Epoch 28/40
# Train Loss: 0.0165 | Val Loss: 0.0150
#
# Epoch 29/40
# Train Loss: 0.0160 | Val Loss: 0.0149
#
# Epoch 30/40
# Train Loss: 0.0157 | Val Loss: 0.0141
#
# Epoch 31/40
# Train Loss: 0.0149 | Val Loss: 0.0136
#
# Epoch 32/40
# Train Loss: 0.0144 | Val Loss: 0.0139
#
# Epoch 33/40
# Train Loss: 0.0142 | Val Loss: 0.0153
#
# Epoch 34/40
# Train Loss: 0.0135 | Val Loss: 0.0135
#
# Epoch 35/40
# Train Loss: 0.0131 | Val Loss: 0.0124
#
# Epoch 36/40
# Train Loss: 0.0130 | Val Loss: 0.0122
#
# Epoch 37/40
# Train Loss: 0.0126 | Val Loss: 0.0122
#
# Epoch 38/40
# Train Loss: 0.0124 | Val Loss: 0.0124
#
# Epoch 39/40
# Train Loss: 0.0119 | Val Loss: 0.0115
#
# Epoch 40/40
# Train Loss: 0.0121 | Val Loss: 0.0113
#
# Running configuration 5/12: {'learning_rate': 0.0001, 'batch_size': 2, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.1221 | Val Loss: 0.0412
#
# Epoch 2/20
# Train Loss: 0.0204 | Val Loss: 0.0162
#
# Epoch 3/20
# Train Loss: 0.0151 | Val Loss: 0.0137
#
# Epoch 4/20
# Train Loss: 0.0132 | Val Loss: 0.0118
#
# Epoch 5/20
# Train Loss: 0.0114 | Val Loss: 0.0104
#
# Epoch 6/20
# Train Loss: 0.0106 | Val Loss: 0.0096
#
# Epoch 7/20
# Train Loss: 0.0103 | Val Loss: 0.0095
#
# Epoch 8/20
# Train Loss: 0.0096 | Val Loss: 0.0100
#
# Epoch 9/20
# Train Loss: 0.0091 | Val Loss: 0.0090
#
# Epoch 10/20
# Train Loss: 0.0088 | Val Loss: 0.0085
#
# Epoch 11/20
# Train Loss: 0.0090 | Val Loss: 0.0085
#
# Epoch 12/20
# Train Loss: 0.0083 | Val Loss: 0.0076
#
# Epoch 13/20
# Train Loss: 0.0078 | Val Loss: 0.0078
#
# Epoch 14/20
# Train Loss: 0.0077 | Val Loss: 0.0077
#
# Epoch 15/20
# Train Loss: 0.0075 | Val Loss: 0.0075
#
# Epoch 16/20
# Train Loss: 0.0075 | Val Loss: 0.0074
#
# Epoch 17/20
# Train Loss: 0.0075 | Val Loss: 0.0075
#
# Epoch 18/20
# Train Loss: 0.0072 | Val Loss: 0.0080
#
# Epoch 19/20
# Train Loss: 0.0071 | Val Loss: 0.0072
#
# Epoch 20/20
# Train Loss: 0.0077 | Val Loss: 0.0074
#
# Running configuration 6/12: {'learning_rate': 0.0001, 'batch_size': 2, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.1541 | Val Loss: 0.0515
#
# Epoch 2/40
# Train Loss: 0.0234 | Val Loss: 0.0190
#
# Epoch 3/40
# Train Loss: 0.0165 | Val Loss: 0.0143
#
# Epoch 4/40
# Train Loss: 0.0138 | Val Loss: 0.0118
#
# Epoch 5/40
# Train Loss: 0.0119 | Val Loss: 0.0117
#
# Epoch 6/40
# Train Loss: 0.0108 | Val Loss: 0.0095
#
# Epoch 7/40
# Train Loss: 0.0101 | Val Loss: 0.0087
#
# Epoch 8/40
# Train Loss: 0.0095 | Val Loss: 0.0088
#
# Epoch 9/40
# Train Loss: 0.0092 | Val Loss: 0.0084
#
# Epoch 10/40
# Train Loss: 0.0087 | Val Loss: 0.0082
#
# Epoch 11/40
# Train Loss: 0.0086 | Val Loss: 0.0090
#
# Epoch 12/40
# Train Loss: 0.0083 | Val Loss: 0.0085
#
# Epoch 13/40
# Train Loss: 0.0079 | Val Loss: 0.0076
#
# Epoch 14/40
# Train Loss: 0.0083 | Val Loss: 0.0079
#
# Epoch 15/40
# Train Loss: 0.0078 | Val Loss: 0.0072
#
# Epoch 16/40
# Train Loss: 0.0073 | Val Loss: 0.0071
#
# Epoch 17/40
# Train Loss: 0.0073 | Val Loss: 0.0069
#
# Epoch 18/40
# Train Loss: 0.0071 | Val Loss: 0.0075
#
# Epoch 19/40
# Train Loss: 0.0072 | Val Loss: 0.0069
#
# Epoch 20/40
# Train Loss: 0.0071 | Val Loss: 0.0072
#
# Epoch 21/40
# Train Loss: 0.0069 | Val Loss: 0.0065
#
# Epoch 22/40
# Train Loss: 0.0069 | Val Loss: 0.0071
#
# Epoch 23/40
# Train Loss: 0.0066 | Val Loss: 0.0067
#
# Epoch 24/40
# Train Loss: 0.0067 | Val Loss: 0.0064
#
# Epoch 25/40
# Train Loss: 0.0065 | Val Loss: 0.0065
#
# Epoch 26/40
# Train Loss: 0.0066 | Val Loss: 0.0070
#
# Epoch 27/40
# Train Loss: 0.0064 | Val Loss: 0.0064
#
# Epoch 28/40
# Train Loss: 0.0062 | Val Loss: 0.0065
#
# Epoch 29/40
# Train Loss: 0.0061 | Val Loss: 0.0064
#
# Epoch 30/40
# Train Loss: 0.0061 | Val Loss: 0.0063
#
# Epoch 31/40
# Train Loss: 0.0061 | Val Loss: 0.0065
#
# Epoch 32/40
# Train Loss: 0.0062 | Val Loss: 0.0072
#
# Epoch 33/40
# Train Loss: 0.0062 | Val Loss: 0.0064
#
# Epoch 34/40
# Train Loss: 0.0059 | Val Loss: 0.0066
#
# Epoch 35/40
# Train Loss: 0.0060 | Val Loss: 0.0064
#
# Epoch 36/40
# Train Loss: 0.0060 | Val Loss: 0.0061
#
# Epoch 37/40
# Train Loss: 0.0059 | Val Loss: 0.0068
#
# Epoch 38/40
# Train Loss: 0.0058 | Val Loss: 0.0063
#
# Epoch 39/40
# Train Loss: 0.0058 | Val Loss: 0.0062
#
# Epoch 40/40
# Train Loss: 0.0057 | Val Loss: 0.0063
#
# Running configuration 7/12: {'learning_rate': 0.0001, 'batch_size': 4, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.2188 | Val Loss: 0.2213
#
# Epoch 2/20
# Train Loss: 0.0449 | Val Loss: 0.0419
#
# Epoch 3/20
# Train Loss: 0.0242 | Val Loss: 0.0221
#
# Epoch 4/20
# Train Loss: 0.0202 | Val Loss: 0.0180
#
# Epoch 5/20
# Train Loss: 0.0173 | Val Loss: 0.0148
#
# Epoch 6/20
# Train Loss: 0.0152 | Val Loss: 0.0131
#
# Epoch 7/20
# Train Loss: 0.0141 | Val Loss: 0.0115
#
# Epoch 8/20
# Train Loss: 0.0123 | Val Loss: 0.0116
#
# Epoch 9/20
# Train Loss: 0.0116 | Val Loss: 0.0104
#
# Epoch 10/20
# Train Loss: 0.0112 | Val Loss: 0.0099
#
# Epoch 11/20
# Train Loss: 0.0103 | Val Loss: 0.0097
#
# Epoch 12/20
# Train Loss: 0.0098 | Val Loss: 0.0092
#
# Epoch 13/20
# Train Loss: 0.0101 | Val Loss: 0.0095
#
# Epoch 14/20
# Train Loss: 0.0102 | Val Loss: 0.0091
#
# Epoch 15/20
# Train Loss: 0.0092 | Val Loss: 0.0086
#
# Epoch 16/20
# Train Loss: 0.0090 | Val Loss: 0.0085
#
# Epoch 17/20
# Train Loss: 0.0086 | Val Loss: 0.0078
#
# Epoch 18/20
# Train Loss: 0.0083 | Val Loss: 0.0078
#
# Epoch 19/20
# Train Loss: 0.0080 | Val Loss: 0.0077
#
# Epoch 20/20
# Train Loss: 0.0081 | Val Loss: 0.0077
#
# Running configuration 8/12: {'learning_rate': 0.0001, 'batch_size': 4, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.3040 | Val Loss: 0.2720
#
# Epoch 2/40
# Train Loss: 0.0568 | Val Loss: 0.0473
#
# Epoch 3/40
# Train Loss: 0.0255 | Val Loss: 0.0242
#
# Epoch 4/40
# Train Loss: 0.0214 | Val Loss: 0.0176
#
# Epoch 5/40
# Train Loss: 0.0175 | Val Loss: 0.0158
#
# Epoch 6/40
# Train Loss: 0.0157 | Val Loss: 0.0136
#
# Epoch 7/40
# Train Loss: 0.0134 | Val Loss: 0.0128
#
# Epoch 8/40
# Train Loss: 0.0124 | Val Loss: 0.0114
#
# Epoch 9/40
# Train Loss: 0.0120 | Val Loss: 0.0117
#
# Epoch 10/40
# Train Loss: 0.0119 | Val Loss: 0.0113
#
# Epoch 11/40
# Train Loss: 0.0109 | Val Loss: 0.0099
#
# Epoch 12/40
# Train Loss: 0.0103 | Val Loss: 0.0093
#
# Epoch 13/40
# Train Loss: 0.0100 | Val Loss: 0.0093
#
# Epoch 14/40
# Train Loss: 0.0097 | Val Loss: 0.0088
#
# Epoch 15/40
# Train Loss: 0.0095 | Val Loss: 0.0086
#
# Epoch 16/40
# Train Loss: 0.0089 | Val Loss: 0.0081
#
# Epoch 17/40
# Train Loss: 0.0089 | Val Loss: 0.0082
#
# Epoch 18/40
# Train Loss: 0.0086 | Val Loss: 0.0083
#
# Epoch 19/40
# Train Loss: 0.0086 | Val Loss: 0.0078
#
# Epoch 20/40
# Train Loss: 0.0083 | Val Loss: 0.0078
#
# Epoch 21/40
# Train Loss: 0.0083 | Val Loss: 0.0075
#
# Epoch 22/40
# Train Loss: 0.0083 | Val Loss: 0.0077
#
# Epoch 23/40
# Train Loss: 0.0084 | Val Loss: 0.0078
#
# Epoch 24/40
# Train Loss: 0.0085 | Val Loss: 0.0076
#
# Epoch 25/40
# Train Loss: 0.0083 | Val Loss: 0.0074
#
# Epoch 26/40
# Train Loss: 0.0082 | Val Loss: 0.0075
#
# Epoch 27/40
# Train Loss: 0.0078 | Val Loss: 0.0073
#
# Epoch 28/40
# Train Loss: 0.0076 | Val Loss: 0.0073
#
# Epoch 29/40
# Train Loss: 0.0072 | Val Loss: 0.0070
#
# Epoch 30/40
# Train Loss: 0.0072 | Val Loss: 0.0072
#
# Epoch 31/40
# Train Loss: 0.0069 | Val Loss: 0.0069
#
# Epoch 32/40
# Train Loss: 0.0069 | Val Loss: 0.0069
#
# Epoch 33/40
# Train Loss: 0.0069 | Val Loss: 0.0069
#
# Epoch 34/40
# Train Loss: 0.0068 | Val Loss: 0.0067
#
# Epoch 35/40
# Train Loss: 0.0067 | Val Loss: 0.0073
#
# Epoch 36/40
# Train Loss: 0.0069 | Val Loss: 0.0081
#
# Epoch 37/40
# Train Loss: 0.0067 | Val Loss: 0.0071
#
# Epoch 38/40
# Train Loss: 0.0067 | Val Loss: 0.0068
#
# Epoch 39/40
# Train Loss: 0.0069 | Val Loss: 0.0068
#
# Epoch 40/40
# Train Loss: 0.0067 | Val Loss: 0.0068
#
# Running configuration 9/12: {'learning_rate': 0.001, 'batch_size': 2, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.0710 | Val Loss: 0.0223
#
# Epoch 2/20
# Train Loss: 0.0199 | Val Loss: 0.0154
#
# Epoch 3/20
# Train Loss: 0.0155 | Val Loss: 0.0128
#
# Epoch 4/20
# Train Loss: 0.0125 | Val Loss: 0.0100
#
# Epoch 5/20
# Train Loss: 0.0121 | Val Loss: 0.0100
#
# Epoch 6/20
# Train Loss: 0.0105 | Val Loss: 0.0092
#
# Epoch 7/20
# Train Loss: 0.0100 | Val Loss: 0.0083
#
# Epoch 8/20
# Train Loss: 0.0091 | Val Loss: 0.0076
#
# Epoch 9/20
# Train Loss: 0.0089 | Val Loss: 0.0076
#
# Epoch 10/20
# Train Loss: 0.0084 | Val Loss: 0.0079
#
# Epoch 11/20
# Train Loss: 0.0083 | Val Loss: 0.0086
#
# Epoch 12/20
# Train Loss: 0.0081 | Val Loss: 0.0070
#
# Epoch 13/20
# Train Loss: 0.0077 | Val Loss: 0.0070
#
# Epoch 14/20
# Train Loss: 0.0077 | Val Loss: 0.0072
#
# Epoch 15/20
# Train Loss: 0.0080 | Val Loss: 0.0068
#
# Epoch 16/20
# Train Loss: 0.0075 | Val Loss: 0.0066
#
# Epoch 17/20
# Train Loss: 0.0083 | Val Loss: 0.0083
#
# Epoch 18/20
# Train Loss: 0.0078 | Val Loss: 0.0068
#
# Epoch 19/20
# Train Loss: 0.0074 | Val Loss: 0.0067
#
# Epoch 20/20
# Train Loss: 0.0074 | Val Loss: 0.0065
#
# Running configuration 10/12: {'learning_rate': 0.001, 'batch_size': 2, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.0737 | Val Loss: 0.0221
#
# Epoch 2/40
# Train Loss: 0.0196 | Val Loss: 0.0155
#
# Epoch 3/40
# Train Loss: 0.0145 | Val Loss: 0.0130
#
# Epoch 4/40
# Train Loss: 0.0120 | Val Loss: 0.0103
#
# Epoch 5/40
# Train Loss: 0.0101 | Val Loss: 0.0088
#
# Epoch 6/40
# Train Loss: 0.0095 | Val Loss: 0.0088
#
# Epoch 7/40
# Train Loss: 0.0108 | Val Loss: 0.0086
#
# Epoch 8/40
# Train Loss: 0.0095 | Val Loss: 0.0087
#
# Epoch 9/40
# Train Loss: 0.0086 | Val Loss: 0.0084
#
# Epoch 10/40
# Train Loss: 0.0087 | Val Loss: 0.0077
#
# Epoch 11/40
# Train Loss: 0.0081 | Val Loss: 0.0076
#
# Epoch 12/40
# Train Loss: 0.0079 | Val Loss: 0.0075
#
# Epoch 13/40
# Train Loss: 0.0072 | Val Loss: 0.0067
#
# Epoch 14/40
# Train Loss: 0.0073 | Val Loss: 0.0068
#
# Epoch 15/40
# Train Loss: 0.0078 | Val Loss: 0.0066
#
# Epoch 16/40
# Train Loss: 0.0071 | Val Loss: 0.0065
#
# Epoch 17/40
# Train Loss: 0.0070 | Val Loss: 0.0062
#
# Epoch 18/40
# Train Loss: 0.0067 | Val Loss: 0.0068
#
# Epoch 19/40
# Train Loss: 0.0069 | Val Loss: 0.0065
#
# Epoch 20/40
# Train Loss: 0.0064 | Val Loss: 0.0061
#
# Epoch 21/40
# Train Loss: 0.0064 | Val Loss: 0.0069
#
# Epoch 22/40
# Train Loss: 0.0070 | Val Loss: 0.0062
#
# Epoch 23/40
# Train Loss: 0.0065 | Val Loss: 0.0059
#
# Epoch 24/40
# Train Loss: 0.0062 | Val Loss: 0.0060
#
# Epoch 25/40
# Train Loss: 0.0063 | Val Loss: 0.0065
#
# Epoch 26/40
# Train Loss: 0.0062 | Val Loss: 0.0067
#
# Epoch 27/40
# Train Loss: 0.0065 | Val Loss: 0.0063
#
# Epoch 28/40
# Train Loss: 0.0062 | Val Loss: 0.0067
#
# Epoch 29/40
# Train Loss: 0.0062 | Val Loss: 0.0060
#
# Epoch 30/40
# Train Loss: 0.0061 | Val Loss: 0.0060
#
# Epoch 31/40
# Train Loss: 0.0058 | Val Loss: 0.0063
#
# Epoch 32/40
# Train Loss: 0.0059 | Val Loss: 0.0059
#
# Epoch 33/40
# Train Loss: 0.0058 | Val Loss: 0.0058
#
# Epoch 34/40
# Train Loss: 0.0058 | Val Loss: 0.0060
#
# Epoch 35/40
# Train Loss: 0.0058 | Val Loss: 0.0057
#
# Epoch 36/40
# Train Loss: 0.0056 | Val Loss: 0.0057
#
# Epoch 37/40
# Train Loss: 0.0058 | Val Loss: 0.0059
#
# Epoch 38/40
# Train Loss: 0.0057 | Val Loss: 0.0058
#
# Epoch 39/40
# Train Loss: 0.0059 | Val Loss: 0.0056
#
# Epoch 40/40
# Train Loss: 0.0056 | Val Loss: 0.0054
#
# Running configuration 11/12: {'learning_rate': 0.001, 'batch_size': 4, 'num_epochs': 20, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/20
# Train Loss: 0.1116 | Val Loss: 0.0311
#
# Epoch 2/20
# Train Loss: 0.0253 | Val Loss: 0.0207
#
# Epoch 3/20
# Train Loss: 0.0200 | Val Loss: 0.0176
#
# Epoch 4/20
# Train Loss: 0.0166 | Val Loss: 0.0145
#
# Epoch 5/20
# Train Loss: 0.0138 | Val Loss: 0.0116
#
# Epoch 6/20
# Train Loss: 0.0116 | Val Loss: 0.0110
#
# Epoch 7/20
# Train Loss: 0.0114 | Val Loss: 0.0089
#
# Epoch 8/20
# Train Loss: 0.0101 | Val Loss: 0.0093
#
# Epoch 9/20
# Train Loss: 0.0096 | Val Loss: 0.0083
#
# Epoch 10/20
# Train Loss: 0.0090 | Val Loss: 0.0090
#
# Epoch 11/20
# Train Loss: 0.0084 | Val Loss: 0.0071
#
# Epoch 12/20
# Train Loss: 0.0087 | Val Loss: 0.0076
#
# Epoch 13/20
# Train Loss: 0.0081 | Val Loss: 0.0072
#
# Epoch 14/20
# Train Loss: 0.0078 | Val Loss: 0.0071
#
# Epoch 15/20
# Train Loss: 0.0078 | Val Loss: 0.0075
#
# Epoch 16/20
# Train Loss: 0.0075 | Val Loss: 0.0067
#
# Epoch 17/20
# Train Loss: 0.0075 | Val Loss: 0.0067
#
# Epoch 18/20
# Train Loss: 0.0076 | Val Loss: 0.0064
#
# Epoch 19/20
# Train Loss: 0.0071 | Val Loss: 0.0067
#
# Epoch 20/20
# Train Loss: 0.0070 | Val Loss: 0.0064
#
# Running configuration 12/12: {'learning_rate': 0.001, 'batch_size': 4, 'num_epochs': 40, 'loss_function': 'BCEWithLogitsLoss'}
#
# Epoch 1/40
# Train Loss: 0.1446 | Val Loss: 0.0384
#
# Epoch 2/40
# Train Loss: 0.0242 | Val Loss: 0.0281
#
# Epoch 3/40
# Train Loss: 0.0203 | Val Loss: 0.0173
#
# Epoch 4/40
# Train Loss: 0.0186 | Val Loss: 0.0149
#
# Epoch 5/40
# Train Loss: 0.0154 | Val Loss: 0.0138
#
# Epoch 6/40
# Train Loss: 0.0129 | Val Loss: 0.0121
#
# Epoch 7/40
# Train Loss: 0.0120 | Val Loss: 0.0097
#
# Epoch 8/40
# Train Loss: 0.0111 | Val Loss: 0.0135
#
# Epoch 9/40
# Train Loss: 0.0101 | Val Loss: 0.0093
#
# Epoch 10/40
# Train Loss: 0.0097 | Val Loss: 0.0091
#
# Epoch 11/40
# Train Loss: 0.0099 | Val Loss: 0.0078
#
# Epoch 12/40
# Train Loss: 0.0089 | Val Loss: 0.0082
#
# Epoch 13/40
# Train Loss: 0.0087 | Val Loss: 0.0080
#
# Epoch 14/40
# Train Loss: 0.0082 | Val Loss: 0.0075
#
# Epoch 15/40
# Train Loss: 0.0083 | Val Loss: 0.0071
#
# Epoch 16/40
# Train Loss: 0.0086 | Val Loss: 0.0072
#
# Epoch 17/40
# Train Loss: 0.0083 | Val Loss: 0.0074
#
# Epoch 18/40
# Train Loss: 0.0079 | Val Loss: 0.0068
#
# Epoch 19/40
# Train Loss: 0.0077 | Val Loss: 0.0069
#
# Epoch 20/40
# Train Loss: 0.0076 | Val Loss: 0.0072
#
# Epoch 21/40
# Train Loss: 0.0071 | Val Loss: 0.0064
#
# Epoch 22/40
# Train Loss: 0.0070 | Val Loss: 0.0063
#
# Epoch 23/40
# Train Loss: 0.0068 | Val Loss: 0.0066
#
# Epoch 24/40
# Train Loss: 0.0068 | Val Loss: 0.0068
#
# Epoch 25/40
# Train Loss: 0.0070 | Val Loss: 0.0063
#
# Epoch 26/40
# Train Loss: 0.0067 | Val Loss: 0.0063
#
# Epoch 27/40
# Train Loss: 0.0066 | Val Loss: 0.0068
#
# Epoch 28/40
# Train Loss: 0.0065 | Val Loss: 0.0061
#
# Epoch 29/40
# Train Loss: 0.0064 | Val Loss: 0.0063
#
# Epoch 30/40
# Train Loss: 0.0062 | Val Loss: 0.0058
#
# Epoch 31/40
# Train Loss: 0.0063 | Val Loss: 0.0061
#
# Epoch 32/40
# Train Loss: 0.0060 | Val Loss: 0.0061
#
# Epoch 33/40
# Train Loss: 0.0062 | Val Loss: 0.0069
#
# Epoch 34/40
# Train Loss: 0.0071 | Val Loss: 0.0069
#
# Epoch 35/40
# Train Loss: 0.0072 | Val Loss: 0.0061
#
# Epoch 36/40
# Train Loss: 0.0064 | Val Loss: 0.0062
#
# Epoch 37/40
# Train Loss: 0.0060 | Val Loss: 0.0057
#
# Epoch 38/40
# Train Loss: 0.0066 | Val Loss: 0.0065
#
# Epoch 39/40
# Train Loss: 0.0063 | Val Loss: 0.0064
#
# Epoch 40/40
# Train Loss: 0.0062 | Val Loss: 0.0057
